# %% [markdown]
# Exploratory Data Analysis (EDA)
# ===============================
# ___
# > Exploring the relavent content of [austraits-7.0.0](https://zenodo.org/records/15718081), specifically "austraits-7.0.0.zip".
# >
# > The extracted austraits-7.0.0 folder is excluded from github due to its extracted size, but the zip file is included.
# >
# > The data is being explored with the problem statement:
# >
# > "Develop machine learning to identify an unknow native plant entity based on easily measurable traits in the field".

# %% [markdown]
# # Glossary
# ___
# References:
#
# [www.merriam-webster.com](https://www.merriam-webster.com)
#
# [thedailyeco.com: What is a Whirl in Biology](https://www.thedailyeco.com/what-is-a-whorl-in-biology-218.html)
#
# [wikipedia.org: Perianth](https://en.wikipedia.org/wiki/Perianth)
#
# [sciencefacts.net](https://www.sciencefacts.net/)
#
# ![Leaf and Flower Anatomy](leaf_and_flower_anatomy.png)
#
# | Name | Description |
# |:-----|:------------|
# |  |  |
# | adaxial | Facing towards the stem of a plant. |
# | adaxial | Facing away from the stem of a plant. |
# | androecium | Flower: Male reproductive organs. |
# | anther | Flower: The tip of the stamen and consisting of lobes called thecae, which contain polen sacs. |
# | anthesis | Flower: Period during which a flower is in the stages of opening. |
# | apex | Leaf: Tip of the leaf. |
# | axil | Leaf: Crotch formed between stem and pentiole. |
# | calyx | Flower: Outer whorl of flower that protect the flower bud before it opens and forms part of the perianth, which includes the petals. The calyx is comprised of multiple leaf-like 'sepals'. |
# | carpel | Flower: Female reproductive part of flower, including ovary, style and stigma. |
# | corolla | Flower: The petals. |
# | gynoecium | Female reproductive organs.
# | lamina (blade) | Leaf: Flat expanded part of the leaf where photosynthesis and gas exchange takes place. |
# | leaf whorl / flower whorl | Flower/Leaf: Separately identifiable segments/sections, indicatd by alternate leaves or leaf clusters for leaves, or peduncle, clyx, corolla, androecium and gynoecium for flowers. |
# | midrib | Leaf: Central vein of the leaf, from the pentiole to the apex. |
# | ovary | Flower: Protects the ovules. |
# | ovule | Flower: Female reproductive cells. |
# | peduncle | The flower stalk. |
# | perianth | The calyx and petals protecting the flower. Flowers with a perianth are called dressed flowers (clamídeas), while naked flowers do not have a perianth. |
# | petiole | Leaf: Stalk connecting the leaf blade to the plant stem. |
# | recepticule | Flower: The structure immediately above the flower stalk and the base the other floral whorls are attached. |
# | sepal | The multiple leaf-like parts forming the calyx. |
# | stamen | Flower: Male reproductive part of the flower, including the anther and filament. |
# | stigma | Flower: sticky head of the carpel, for receiving and germinating pollen grains. |
# | stipule | Leaf: Leaf-like protrusions found on some plants, usually in pairs, extending from the base of the pentiole. |
# | style | Flower: Slender stalk structure connecting from the ovary to the stigma, and housing the pollen tube. |
# | taxon | Grouping of organisms, such as by ranking, like `family`, `genus` or `species`. For example, taxon rank might be 'species', with the taxon name being 'Acanthocarpus preissii', such that "the species is Acanthocarpus preissii". |

# %% [markdown]
# # Overview
# ___
# austraits-7.0.0 consists of 13 tables, saved in various formats. Of particular interest serving the problem statement:
#
# * schema
# >  * YAML file.
# >  * Describes structure of all the tables, definition of fields, and the relationships between the tables.
#
# * taxa
# >  * CSV file containing `taxon_name` with `taxon_rank`, `genus` and `family` fields.
#
# * traits
# >  * CSV file with 26 columns and 1798215 records.
# >  * One or more row entries belong to a single `observation_id`, representing a specific `taxon_name` from a particular `dataset_id`.
# >  * Each entry of the `observation_id`, or just '_**observation**_', is for a particular `trait_name`, or just '_**trait**_'.
# >    * -> Each row is a trait, with `value` and, if applicable, `unit` units, but there may be more than one entry for different `value_type`'s, such as 'minimum' and 'maximum', and possibly other fields.
# >  * Consider checking uniqueness of row entries.
# >  * See "1.1 First 10 rows", below.
#
# * definitions
# >  * YAML file with 532 keys in the top level.
# >  * Each top level key is a possible `trait_name` entry in the traits table.
# >    * Trait keys include keys `description` and `type` (categorical or numerical) and can includes keys `units`, `allowed_values_min` and `allowed_values_max`, among others.
#
# * methods
# >  * CSV file containing the methodology of meausring each trait for respective dataset sources.

# %%
# Imports
import pandas as pd

# %% [markdown]
# # 1. traits.csv
# ___

# %%
traits_csv = 'austraits-7.0.0/traits.csv'
traits_df = pd.read_csv(traits_csv, encoding='ISO-8859-1', low_memory=False)

# %% [markdown]
# ## 1.1. First 10 rows
# > View first few rows to determine type of data avaialble.

# %%
# Don't skip columns or rows in output
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
traits_df.head(10)
# Out:
#   dataset_id                   taxon_name  observation_id         trait_name  \
# 0  ABRS_1981  Acanthocarpus canaliculatus               1  leaf_compoundness
# 1  ABRS_1981  Acanthocarpus canaliculatus               1        seed_length
# 2  ABRS_1981        Acanthocarpus humilis               2  leaf_compoundness
# 3  ABRS_1981    Acanthocarpus parviflorus               3  leaf_compoundness
# 4  ABRS_1981       Acanthocarpus preissii               4  leaf_compoundness
# 5  ABRS_1981       Acanthocarpus preissii               4        seed_length
# 6  ABRS_1981       Acanthocarpus preissii               4        seed_length
# 7  ABRS_1981       Acanthocarpus robustus               5  leaf_compoundness
# 8  ABRS_1981      Acanthocarpus rupestris               6  leaf_compoundness
# 9  ABRS_1981      Acanthocarpus rupestris               6        seed_length
#
#     value unit entity_type value_type basis_of_value replicates  \
# 0  simple  NaN     species       mode   expert_score        NaN
# 1       3   mm     species    maximum    measurement        NaN
# 2  simple  NaN     species       mode   expert_score        NaN
# 3  simple  NaN     species       mode   expert_score        NaN
# 4  simple  NaN     species       mode   expert_score        NaN
# 5       4   mm     species    minimum    measurement        NaN
# 6       5   mm     species    maximum    measurement        NaN
# 7  simple  NaN     species       mode   expert_score        NaN
# 8  simple  NaN     species       mode   expert_score        NaN
# 9     2.5   mm     species    maximum    measurement        NaN
#
#       basis_of_record life_stage population_id  individual_id  \
# 0  preserved_specimen      adult           NaN            NaN
# 1  preserved_specimen      adult           NaN            NaN
# 2  preserved_specimen      adult           NaN            NaN
# 3  preserved_specimen      adult           NaN            NaN
# 4  preserved_specimen      adult           NaN            NaN
# 5  preserved_specimen      adult           NaN            NaN
# 6  preserved_specimen      adult           NaN            NaN
# 7  preserved_specimen      adult           NaN            NaN
# 8  preserved_specimen      adult           NaN            NaN
# 9  preserved_specimen      adult           NaN            NaN
#
#    repeat_measurements_id  temporal_context_id source_id  location_id  \
# 0                     NaN                  1.0       NaN          NaN
# 1                     NaN                  1.0       NaN          NaN
# 2                     NaN                  1.0       NaN          NaN
# 3                     NaN                  1.0       NaN          NaN
# 4                     NaN                  1.0       NaN          NaN
# 5                     NaN                  1.0       NaN          NaN
# 6                     NaN                  1.0       NaN          NaN
# 7                     NaN                  1.0       NaN          NaN
# 8                     NaN                  1.0       NaN          NaN
# 9                     NaN                  1.0       NaN          NaN
#
#    entity_context_id  plot_context_id  treatment_context_id collection_date  \
# 0                NaN              NaN                   NaN    unknown/2015
# 1                NaN              NaN                   NaN    unknown/2015
# 2                NaN              NaN                   NaN    unknown/2015
# 3                NaN              NaN                   NaN    unknown/2015
# 4                NaN              NaN                   NaN    unknown/2015
# 5                NaN              NaN                   NaN    unknown/2015
# 6                NaN              NaN                   NaN    unknown/2015
# 7                NaN              NaN                   NaN    unknown/2015
# 8                NaN              NaN                   NaN    unknown/2015
# 9                NaN              NaN                   NaN    unknown/2015
#
#   measurement_remarks  method_id  method_context_id  \
# 0                 NaN        1.0                NaN
# 1                 NaN        1.0                NaN
# 2                 NaN        1.0                NaN
# 3                 NaN        1.0                NaN
# 4                 NaN        1.0                NaN
# 5                 NaN        1.0                NaN
# 6                 NaN        1.0                NaN
# 7                 NaN        1.0                NaN
# 8                 NaN        1.0                NaN
# 9                 NaN        1.0                NaN
#
#                  original_name
# 0  Acanthocarpus canaliculatus
# 1  Acanthocarpus canaliculatus
# 2        Acanthocarpus humilis
# 3    Acanthocarpus parviflorus
# 4       Acanthocarpus preissii
# 5       Acanthocarpus preissii
# 6       Acanthocarpus preissii
# 7       Acanthocarpus robustus
# 8      Acanthocarpus rupestris
# 9      Acanthocarpus rupestris

# %% [markdown]
# * **An issue here is the value_type indicates entries are aggregates/minimums/maximums.**
#   * Not having all the raw data may make it difficult to produce a well geenralised model.
#   * The features predicted on will also have to be aggregates/minimums/maximums if/when using features of this type.
#   * There may be too few samples below the genus level, or family level in some cases, to model with.

# %% [markdown]
# ## 1.2. Total Records in traits.csv

# %%
print(f'Total traits records: {len(traits_df)}')
# Out:
# Total traits records: 1798215

# %% [markdown]
# ## 1.3. Column Names and Data Types

# %%
traits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1798215 entries, 0 to 1798214
# Data columns (total 26 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   dataset_id              object
#  1   taxon_name              object
#  2   observation_id          int64
#  3   trait_name              object
#  4   value                   object
#  5   unit                    object
#  6   entity_type             object
#  7   value_type              object
#  8   basis_of_value          object
#  9   replicates              object
#  10  basis_of_record         object
#  11  life_stage              object
#  12  population_id           object
#  13  individual_id           float64
#  14  repeat_measurements_id  float64
#  15  temporal_context_id     float64
#  16  source_id               object
#  17  location_id             float64
#  18  entity_context_id       float64
#  19  plot_context_id         float64
#  20  treatment_context_id    float64
#  21  collection_date         object
#  22  measurement_remarks     object
#  23  method_id               float64
#  24  method_context_id       float64
#  25  original_name           object
# dtypes: float64(9), int64(1), object(16)
# memory usage: 356.7+ MB

# %% [markdown]
# ## 1.4. Total Unique Trait Names

# %%
print(f'Number of unique trait names: {traits_df.trait_name.nunique()}')
# Out:
# Number of unique trait names: 530

# %% [markdown]
# ## 1.5. Entity Types and Counts

# %%
traits_df.entity_type.value_counts()
# Out:
# entity_type
# species           1355931
# individual         322631
# population         118170
# metapopulation        933
# unknown               550
# Name: count, dtype: int64

# %% [markdown]
# This list only represents the source of the data with respect to the entity. For example, does the value come from a single individual, or does it represent a summary statistic for an entire species. An entry of 'species' is not necessarily the taxon rank. For example, an unknown entity could belong to a family, genus, species and subspecies, each of which could have rows in traits.csv.
#
# The `taxon_rank` is available in taxa.csv, by referencing `taxon_name`.

# %% [markdown]
# ## 1.6 Taxon Example

# %%
traits_df[traits_df.taxon_name == 'Abrotanella scapigera']
# Out:
#                dataset_id             taxon_name  observation_id  \
# 9034            ABRS_2022  Abrotanella scapigera               3
# 9035            ABRS_2022  Abrotanella scapigera               3
# 9036            ABRS_2022  Abrotanella scapigera               3
# 56558           ABRS_2023  Abrotanella scapigera               3
# 56559           ABRS_2023  Abrotanella scapigera               3
# 56560           ABRS_2023  Abrotanella scapigera               3
# 56561           ABRS_2023  Abrotanella scapigera               3
# 56562           ABRS_2023  Abrotanella scapigera               3
# 56563           ABRS_2023  Abrotanella scapigera               3
# 56564           ABRS_2023  Abrotanella scapigera               3
# 56565           ABRS_2023  Abrotanella scapigera               3
# 56566           ABRS_2023  Abrotanella scapigera               3
# 56567           ABRS_2023  Abrotanella scapigera               3
# 56568           ABRS_2023  Abrotanella scapigera               3
# 545854        Jordan_2001  Abrotanella scapigera               2
# 545855        Jordan_2001  Abrotanella scapigera               2
# 545856        Jordan_2001  Abrotanella scapigera               2
# 545857        Jordan_2001  Abrotanella scapigera               2
# 545858        Jordan_2001  Abrotanella scapigera               2
# 545859        Jordan_2001  Abrotanella scapigera               2
# 545860        Jordan_2001  Abrotanella scapigera               2
# 571383         Kew_2019_1  Abrotanella scapigera              13
# 593343   Kirkpatrick_2020  Abrotanella scapigera               2
# 593344   Kirkpatrick_2020  Abrotanella scapigera               2
# 697264        Mokany_2015  Abrotanella scapigera               2
# 697265        Mokany_2015  Abrotanella scapigera               2
# 697266        Mokany_2015  Abrotanella scapigera               2
# 1171503     Sjostrom_2006  Abrotanella scapigera               5
# 1171504     Sjostrom_2006  Abrotanella scapigera               5
# 1171505     Sjostrom_2006  Abrotanella scapigera               5
# 1171506     Sjostrom_2006  Abrotanella scapigera               5
# 1456749         Wenk_2022  Abrotanella scapigera              22
# 1456750         Wenk_2022  Abrotanella scapigera              22
# 1516985         Wenk_2023  Abrotanella scapigera              22
#
#                          trait_name                           value unit  \
# 9034                   life_history                       perennial  NaN
# 9035              plant_growth_form                            herb  NaN
# 9036             woodiness_detailed                      herbaceous  NaN
# 56558                  fruit_colour                           brown  NaN
# 56559              fruit_dehiscence                     indehiscent  NaN
# 56560                  fruit_length                             1.7   mm
# 56561                  fruit_length                             2.2   mm
# 56562                    fruit_type                          achene  NaN
# 56563                   leaf_length                              10   mm
# 56564                   leaf_length                              40   mm
# 56565                   leaf_margin                          entire  NaN
# 56566                    leaf_shape  narrowly_elliptical spathulate  NaN
# 56567                  plant_height                             0.1    m
# 56568    plant_photosynthetic_organ                            leaf  NaN
# 545854          dispersal_appendage                            none  NaN
# 545855             fruit_fleshiness                             dry  NaN
# 545856                 life_history                       perennial  NaN
# 545857                  seed_length                           1.485   mm
# 545858                   seed_width                           0.594   mm
# 545859                     sex_type        hermaphrodite monoecious  NaN
# 545860                    woodiness                      herbaceous  NaN
# 571383                seed_dry_mass                          0.5008   mg
# 593343            seedbank_location          canopy_seedbank_absent  NaN
# 593344                     serotiny                  not_serotinous  NaN
# 697264                    leaf_area                         1189.09  mm2
# 697265                 plant_height                            0.08    m
# 697266                seed_dry_mass                           0.501   mg
# 1171503            fruit_dehiscence                     indehiscent  NaN
# 1171504            fruit_fleshiness                             dry  NaN
# 1171505                  fruit_type                          achene  NaN
# 1171506                    sex_type               polygamodioecious  NaN
# 1456749           plant_growth_form                            herb  NaN
# 1456750          woodiness_detailed                      herbaceous  NaN
# 1516985                life_history                       perennial  NaN
#
#         entity_type value_type basis_of_value replicates     basis_of_record  \
# 9034        species       mode   expert_score        NaN  preserved_specimen
# 9035        species       mode   expert_score        NaN  preserved_specimen
# 9036        species       mode   expert_score        NaN  preserved_specimen
# 56558       species       mode   expert_score        NaN  preserved_specimen
# 56559       species       mode   expert_score        NaN  preserved_specimen
# 56560       species    minimum    measurement        NaN  preserved_specimen
# 56561       species    maximum    measurement        NaN  preserved_specimen
# 56562       species       mode   expert_score        NaN  preserved_specimen
# 56563       species    minimum    measurement        NaN  preserved_specimen
# 56564       species    maximum    measurement        NaN  preserved_specimen
# 56565       species       mode   expert_score        NaN  preserved_specimen
# 56566       species       mode   expert_score        NaN  preserved_specimen
# 56567       species    maximum    measurement        NaN  preserved_specimen
# 56568       species       mode   expert_score        NaN  preserved_specimen
# 545854      species       mode   expert_score        NaN               field
# 545855      species       mode   expert_score        NaN               field
# 545856      species       mode   expert_score        NaN               field
# 545857      species       mean    measurement        NaN               field
# 545858      species       mean    measurement        NaN               field
# 545859      species       mode   expert_score        NaN               field
# 545860      species       mode   expert_score        NaN               field
# 571383   individual       mean    measurement    unknown  preserved_specimen
# 593343      species       mode   expert_score        NaN               field
# 593344      species       mode   expert_score        NaN               field
# 697264      species       mean    measurement        NaN          literature
# 697265      species    maximum    measurement        NaN          literature
# 697266      species       mean    measurement        NaN          literature
# 1171503     species       mode   expert_score        NaN          literature
# 1171504     species       mode   expert_score        NaN          literature
# 1171505     species       mode   expert_score        NaN          literature
# 1171506     species       mode   expert_score        NaN          literature
# 1456749     species       mode   expert_score        NaN  preserved_specimen
# 1456750     species       mode   expert_score        NaN  preserved_specimen
# 1516985     species       mode   expert_score        NaN    literature field
#
#         life_stage population_id  individual_id  repeat_measurements_id  \
# 9034         adult           NaN            NaN                     NaN
# 9035         adult           NaN            NaN                     NaN
# 9036         adult           NaN            NaN                     NaN
# 56558        adult           NaN            NaN                     NaN
# 56559        adult           NaN            NaN                     NaN
# 56560        adult           NaN            NaN                     NaN
# 56561        adult           NaN            NaN                     NaN
# 56562        adult           NaN            NaN                     NaN
# 56563        adult           NaN            NaN                     NaN
# 56564        adult           NaN            NaN                     NaN
# 56565        adult           NaN            NaN                     NaN
# 56566        adult           NaN            NaN                     NaN
# 56567        adult           NaN            NaN                     NaN
# 56568        adult           NaN            NaN                     NaN
# 545854       adult           NaN            NaN                     NaN
# 545855       adult           NaN            NaN                     NaN
# 545856       adult           NaN            NaN                     NaN
# 545857       adult           NaN            NaN                     NaN
# 545858       adult           NaN            NaN                     NaN
# 545859       adult           NaN            NaN                     NaN
# 545860       adult           NaN            NaN                     NaN
# 571383       adult       pop_unk            1.0                     NaN
# 593343       adult           NaN            NaN                     NaN
# 593344       adult           NaN            NaN                     NaN
# 697264       adult           NaN            NaN                     NaN
# 697265       adult           NaN            NaN                     NaN
# 697266       adult           NaN            NaN                     NaN
# 1171503      adult           NaN            NaN                     NaN
# 1171504      adult           NaN            NaN                     NaN
# 1171505      adult           NaN            NaN                     NaN
# 1171506      adult           NaN            NaN                     NaN
# 1456749      adult           NaN            NaN                     NaN
# 1456750      adult           NaN            NaN                     NaN
# 1516985      adult           NaN            NaN                     NaN
#
#          temporal_context_id source_id  location_id  entity_context_id  \
# 9034                     NaN       NaN          NaN                NaN
# 9035                     NaN       NaN          NaN                NaN
# 9036                     NaN       NaN          NaN                NaN
# 56558                    1.0       NaN          NaN                NaN
# 56559                    1.0       NaN          NaN                NaN
# 56560                    1.0       NaN          NaN                NaN
# 56561                    1.0       NaN          NaN                NaN
# 56562                    1.0       NaN          NaN                NaN
# 56563                    1.0       NaN          NaN                NaN
# 56564                    1.0       NaN          NaN                NaN
# 56565                    1.0       NaN          NaN                NaN
# 56566                    1.0       NaN          NaN                NaN
# 56567                    1.0       NaN          NaN                NaN
# 56568                    1.0       NaN          NaN                NaN
# 545854                   NaN       NaN          NaN                NaN
# 545855                   NaN       NaN          NaN                NaN
# 545856                   NaN       NaN          NaN                NaN
# 545857                   NaN       NaN          NaN                NaN
# 545858                   NaN       NaN          NaN                NaN
# 545859                   NaN       NaN          NaN                NaN
# 545860                   NaN       NaN          NaN                NaN
# 571383                   NaN  Kew_2019          NaN                NaN
# 593343                   NaN       NaN          NaN                NaN
# 593344                   NaN       NaN          NaN                NaN
# 697264                   NaN       NaN          NaN                NaN
# 697265                   NaN       NaN          NaN                NaN
# 697266                   NaN       NaN          NaN                NaN
# 1171503                  NaN       NaN          NaN                NaN
# 1171504                  NaN       NaN          NaN                NaN
# 1171505                  NaN       NaN          NaN                NaN
# 1171506                  NaN       NaN          NaN                NaN
# 1456749                  NaN       NaN          NaN                NaN
# 1456750                  NaN       NaN          NaN                NaN
# 1516985                  NaN       NaN          NaN                NaN
#
#          plot_context_id  treatment_context_id collection_date  \
# 9034                 NaN                   NaN    unknown/2022
# 9035                 NaN                   NaN    unknown/2022
# 9036                 NaN                   NaN    unknown/2022
# 56558                NaN                   NaN    unknown/2022
# 56559                NaN                   NaN    unknown/2022
# 56560                NaN                   NaN    unknown/2022
# 56561                NaN                   NaN    unknown/2022
# 56562                NaN                   NaN    unknown/2022
# 56563                NaN                   NaN    unknown/2022
# 56564                NaN                   NaN    unknown/2022
# 56565                NaN                   NaN    unknown/2022
# 56566                NaN                   NaN    unknown/2022
# 56567                NaN                   NaN    unknown/2022
# 56568                NaN                   NaN    unknown/2022
# 545854               NaN                   NaN       2001/2001
# 545855               NaN                   NaN       2001/2001
# 545856               NaN                   NaN       2001/2001
# 545857               NaN                   NaN       2001/2001
# 545858               NaN                   NaN       2001/2001
# 545859               NaN                   NaN       2001/2001
# 545860               NaN                   NaN       2001/2001
# 571383               NaN                   NaN    unknown/2019
# 593343               NaN                   NaN       2020/2020
# 593344               NaN                   NaN       2020/2020
# 697264               NaN                   NaN       2015/2015
# 697265               NaN                   NaN       2015/2015
# 697266               NaN                   NaN       2015/2015
# 1171503              NaN                   NaN       1996/2005
# 1171504              NaN                   NaN       1996/2005
# 1171505              NaN                   NaN       1996/2005
# 1171506              NaN                   NaN       1996/2005
# 1456749              NaN                   NaN    unknown/2022
# 1456750              NaN                   NaN    unknown/2022
# 1516985              NaN                   NaN    unknown/2022
#
#                                        measurement_remarks  method_id  \
# 9034                                                author        1.0
# 9035                                                author        1.0
# 9036                                                author        1.0
# 56558    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56559    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56560    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56561    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56562    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56563    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56564    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56565    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56566    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56567    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 56568    Author: I.R. Thompson; Contributor: John R. Bu...        1.0
# 545854                                                 NaN        1.0
# 545855                                                 NaN        1.0
# 545856                                                 NaN        1.0
# 545857                                                 NaN        1.0
# 545858                                                 NaN        1.0
# 545859                                                 NaN        1.0
# 545860                                                 NaN        1.0
# 571383   MATERIAL: Seed; NOTES: *Seed weights reported ...        1.0
# 593343                                                 NaN        1.0
# 593344                                                 NaN        1.0
# 697264                                                 NaN        1.0
# 697265                                                 NaN        1.0
# 697266                                                 NaN        1.0
# 1171503                                                NaN        1.0
# 1171504                                                NaN        1.0
# 1171505                                                NaN        1.0
# 1171506                                                NaN        1.0
# 1456749                 scraped from online flora: species        1.0
# 1456750                 scraped from online flora: species        1.0
# 1516985                                 floras-scraped: NA        1.0
#
#          method_context_id          original_name
# 9034                   NaN  Abrotanella scapigera
# 9035                   NaN  Abrotanella scapigera
# 9036                   NaN  Abrotanella scapigera
# 56558                 32.0  Abrotanella scapigera
# 56559                  2.0  Abrotanella scapigera
# 56560                 32.0  Abrotanella scapigera
# 56561                 32.0  Abrotanella scapigera
# 56562                 32.0  Abrotanella scapigera
# 56563                 28.0  Abrotanella scapigera
# 56564                 28.0  Abrotanella scapigera
# 56565                 32.0  Abrotanella scapigera
# 56566                 32.0  Abrotanella scapigera
# 56567                 32.0  Abrotanella scapigera
# 56568                 32.0  Abrotanella scapigera
# 545854                 NaN  Abrotanella scapigera
# 545855                 NaN  Abrotanella scapigera
# 545856                 NaN  Abrotanella scapigera
# 545857                 NaN  Abrotanella scapigera
# 545858                 NaN  Abrotanella scapigera
# 545859                 NaN  Abrotanella scapigera
# 545860                 NaN  Abrotanella scapigera
# 571383                 3.0  Abrotanella scapigera
# 593343                 NaN  Abrotanella scapigera
# 593344                 NaN  Abrotanella scapigera
# 697264                 NaN  Abrotanella scapigera
# 697265                 NaN  Abrotanella scapigera
# 697266                 NaN  Abrotanella scapigera
# 1171503                NaN  Abrotanella scapigera
# 1171504                NaN  Abrotanella scapigera
# 1171505                NaN  Abrotanella scapigera
# 1171506                NaN  Abrotanella scapigera
# 1456749                NaN  Abrotanella scapigera
# 1456750                NaN  Abrotanella scapigera
# 1516985                NaN  Abrotanella scapigera

# %% [markdown]
# ## 1.7. Traits Summary
#
# There are 530 unique trait names in this data set, but section '2.1 Trait Definition Count' indicates there are 532 defined. Each is a feature to consider. The taxon name could be considered a dependent variable, but must take the taxon rank into account, which is avaialble in taxa.csv.
#
# A possible vector for identifying an unknown entity could to first use ML to determine the highest avaialble taxa, then use additional ML models to determine each next subordinate taxa.
#
# Section '1.6 Taxon Example', above, shows entries from different `dataset_id`'s. One provides minimum and maximum leaf_length, while another provides average leaf_area. Different entities will likely have variation in avaialble features.

# %%
traits_df[traits_df.taxon_name.str.startswith('Abrotanella')].taxon_name.value_counts()
# Out:
# taxon_name
# Abrotanella nivigena            95
# Abrotanella forsteroides        35
# Abrotanella scapigera           34
# Abrotanella sp. [White_2020]    19
# Name: count, dtype: int64

# %% [markdown]
# # 2. definitions.yml
# ___
# ## 2.1. Trait Definition Count

# %%
import yaml

definitions_yaml = 'austraits-7.0.0/definitions.yml'
with open(definitions_yaml, 'r') as definitions_file:
    definitions_data = yaml.safe_load(definitions_file)

    # Ensure the data is a dictionary
    if isinstance(definitions_data, dict):
        # Print count of top level keys
        print(f'Number of types of traits: {len(definitions_data.keys())}')
    else:
        raise ValueError("YAML file does not contain a dictionary at top level.")
# Out:
# Number of types of traits: 532

# %% [markdown]
# # 3. Trait Selection
# ___
# * To meet the problem statement, features will be selected that are quickly attainable in the field, such as leaf dimensions, fruit colour, ...
# * Given the reduced number of features, the output of the model could be the most likely `taxon_name`'s with the associated probability of each. The probability of the mostl likely taxon_name may typically be well under 50% with a reduced number of features.

# %% [markdown]
# ## 3.1. Grouped Trait List
# * This grouping and sorting of traits allows for easier initial trait selection, as traits can be easily excluded based on units, as well as trait name.
#   * For example, if units are 'um', this would not easily be measurable with simple field instruments.
# * Displaying `unit` and `value_type` also makes any errors easy to identify as they may show as duplicates.
# * It is noteworthy there are value types of mean and raw with many traits having entries for both.

# %%
traits_grouped_df = traits_df[['trait_name', 'unit', 'value_type']].groupby(['trait_name', 'unit', 'value_type']).size().reset_index(name='Counts').sort_values(by=['trait_name', 'unit', 'value_type'], ascending=[True, True, True])
traits_grouped_df
# Out:
#                                             trait_name  \
# 0                              accessory_cost_fraction
# 1                                  accessory_cost_mass
# 2                        atmospheric_CO2_concentration
# 3                                 bark_Al_per_dry_mass
# 4                                  bark_B_per_dry_mass
# 5                                  bark_C_per_dry_mass
# 6                                 bark_Ca_per_dry_mass
# 7                                 bark_Ca_per_dry_mass
# 8                                 bark_Cu_per_dry_mass
# 9                                 bark_Fe_per_dry_mass
# 10                                 bark_K_per_dry_mass
# 11                                 bark_K_per_dry_mass
# 12                                bark_Mg_per_dry_mass
# 13                                bark_Mg_per_dry_mass
# 14                                bark_Mn_per_dry_mass
# 15                                 bark_N_per_dry_mass
# 16                                 bark_N_per_dry_mass
# 17                                bark_Na_per_dry_mass
# 18                                bark_Na_per_dry_mass
# 19                                 bark_P_per_dry_mass
# 20                                 bark_P_per_dry_mass
# 21                                 bark_S_per_dry_mass
# 22                                bark_Zn_per_dry_mass
# 23                               bark_ash_per_dry_mass
# 24                         bark_cellulose_per_dry_mass
# 25                                       bark_delta13C
# 26                                       bark_delta15N
# 27                                        bark_density
# 28                                        bark_density
# 29                      bark_dry_mass_per_surface_area
# 30                            bark_lignin_per_dry_mass
# 31                          bark_modulus_of_elasticity
# 32                          bark_modulus_of_elasticity
# 33                            bark_tannin_per_dry_mass
# 34                                      bark_thickness
# 35                                      bark_thickness
# 36                                bark_thickness_index
# 37                                bark_thickness_index
# 38                     bark_water_content_per_dry_mass
# 39               bark_water_content_per_saturated_mass
# 40                                branch_mass_fraction
# 41           branch_terminal_twig_cross_sectional_area
# 42                         branch_terminal_twig_length
# 43                                          bud_length
# 44                                          bud_length
# 45                                           bud_width
# 46                                           bud_width
# 47                              buds_per_inflorescence
# 48                              buds_per_inflorescence
# 49                          bulk_modulus_of_elasticity
# 50                          bulk_modulus_of_elasticity
# 51                           cell_cross-sectional_area
# 52                                   diaspore_dry_mass
# 53               establishment_light_environment_index
# 54                                 fire_flame_duration
# 55                          fire_fuel_bed_bulk_density
# 56                               fire_fuel_consumption
# 57                                 fire_rate_of_spread
# 58                              fire_smoulder_duration
# 59         fire_time_from_fire_to_50_percent_flowering
# 60         fire_time_from_fire_to_50_percent_flowering
# 61         fire_time_from_fire_to_50_percent_flowering
# 62         fire_time_from_fire_to_50_percent_flowering
# 63         fire_time_from_fire_to_50_percent_flowering
# 64          fire_time_from_fire_to_50_percent_fruiting
# 65          fire_time_from_fire_to_50_percent_fruiting
# 66                    fire_time_from_fire_to_flowering
# 67                    fire_time_from_fire_to_flowering
# 68                    fire_time_from_fire_to_flowering
# 69                    fire_time_from_fire_to_flowering
# 70                    fire_time_from_fire_to_flowering
# 71            fire_time_from_fire_to_flowering_decline
# 72                     fire_time_from_fire_to_fruiting
# 73                     fire_time_from_fire_to_fruiting
# 74                     fire_time_from_fire_to_fruiting
# 75                     fire_time_from_fire_to_fruiting
# 76               fire_time_from_fire_to_peak_flowering
# 77               fire_time_from_fire_to_peak_flowering
# 78               fire_time_from_fire_to_peak_flowering
# 79               fire_time_from_fire_to_peak_flowering
# 80                               fire_time_to_ignition
# 81                            fire_total_burn_duration
# 82                               flower_N_per_dry_mass
# 83                               flower_N_per_dry_mass
# 84                 flower_androecium_structural_merism
# 85                 flower_androecium_structural_merism
# 86                 flower_androecium_structural_merism
# 87           flower_androecium_structural_whorls_count
# 88           flower_androecium_structural_whorls_count
# 89           flower_androecium_structural_whorls_count
# 90                                flower_count_maximum
# 91                                     flower_diameter
# 92                                     flower_diameter
# 93                                     flower_diameter
# 94                        flower_fertile_stamens_count
# 95                        flower_fertile_stamens_count
# 96                        flower_fertile_stamens_count
# 97                              flower_filament_fusion
# 98                              flower_filament_fusion
# 99                              flower_filament_fusion
# 100           flower_filament_fusion_to_inner_perianth
# 101           flower_filament_fusion_to_inner_perianth
# 102           flower_filament_fusion_to_inner_perianth
# 103                                      flower_length
# 104                                      flower_length
# 105                                      flower_length
# 106                                flower_ovary_fusion
# 107                                flower_ovary_fusion
# 108                                flower_ovary_fusion
# 109          flower_ovules_per_functional_carpel_count
# 110          flower_ovules_per_functional_carpel_count
# 111          flower_ovules_per_functional_carpel_count
# 112                             flower_perianth_fusion
# 113                             flower_perianth_fusion
# 114                             flower_perianth_fusion
# 115                             flower_perianth_merism
# 116                             flower_perianth_merism
# 117                             flower_perianth_merism
# 118                        flower_perianth_parts_count
# 119                        flower_perianth_parts_count
# 120                        flower_perianth_parts_count
# 121                       flower_perianth_whorls_count
# 122                       flower_perianth_whorls_count
# 123                       flower_perianth_whorls_count
# 124                      flower_pollen_apertures_count
# 125                      flower_pollen_apertures_count
# 126                      flower_pollen_apertures_count
# 127                               flower_pollen_length
# 128                               flower_pollen_length
# 129                               flower_pollen_length
# 130                    flower_structural_carpels_count
# 131                    flower_structural_carpels_count
# 132                    flower_structural_carpels_count
# 133                                flower_style_fusion
# 134                                flower_style_fusion
# 135                                flower_style_fusion
# 136                              fruit_Ca_per_dry_mass
# 137                              fruit_Ca_per_dry_mass
# 138                               fruit_K_per_dry_mass
# 139                               fruit_K_per_dry_mass
# 140                              fruit_Mg_per_dry_mass
# 141                              fruit_Mg_per_dry_mass
# 142                               fruit_N_per_dry_mass
# 143                               fruit_N_per_dry_mass
# 144                               fruit_P_per_dry_mass
# 145                               fruit_P_per_dry_mass
# 146                               fruit_S_per_dry_mass
# 147                               fruit_S_per_dry_mass
# 148                                     fruit_dry_mass
# 149                                     fruit_dry_mass
# 150                                       fruit_height
# 151                                       fruit_height
# 152                                       fruit_height
# 153                                       fruit_length
# 154                                       fruit_length
# 155                                       fruit_length
# 156                                       fruit_length
# 157                               fruit_wall_thickness
# 158                                        fruit_width
# 159                                        fruit_width
# 160                                        fruit_width
# 161                                        fruit_width
# 162                                        genome_size
# 163                                        genome_size
# 164                                        huber_value
# 165                                        huber_value
# 166                         hydraulic_safety_margin_50
# 167                         hydraulic_safety_margin_50
# 168                         hydraulic_safety_margin_88
# 169                         hydraulic_safety_margin_88
# 170                     integrated_plant_transpiration
# 171                     integrated_plant_transpiration
# 172                               leaf_Al_per_dry_mass
# 173                                leaf_B_per_dry_mass
# 174                                leaf_B_per_dry_mass
# 175                                      leaf_CN_ratio
# 176                                      leaf_CN_ratio
# 177                                leaf_C_per_dry_mass
# 178                                leaf_C_per_dry_mass
# 179                               leaf_Ca_per_dry_mass
# 180                               leaf_Ca_per_dry_mass
# 181                               leaf_Cl_per_dry_mass
# 182                               leaf_Co_per_dry_mass
# 183                               leaf_Cr_per_dry_mass
# 184                               leaf_Cu_per_dry_mass
# 185                               leaf_Cu_per_dry_mass
# 186                               leaf_Fe_per_dry_mass
# 187                               leaf_Fe_per_dry_mass
# 188                                    leaf_K_per_area
# 189                                leaf_K_per_dry_mass
# 190                                leaf_K_per_dry_mass
# 191                               leaf_Mg_per_dry_mass
# 192                               leaf_Mg_per_dry_mass
# 193                               leaf_Mn_per_dry_mass
# 194                               leaf_Mn_per_dry_mass
# 195                               leaf_Mo_per_dry_mass
# 196                               leaf_Mo_per_dry_mass
# 197                                      leaf_NP_ratio
# 198                                      leaf_NP_ratio
# 199                                    leaf_N_per_area
# 200                                    leaf_N_per_area
# 201                                leaf_N_per_dry_mass
# 202                                leaf_N_per_dry_mass
# 203                                  leaf_N_resorption
# 204                               leaf_Na_per_dry_mass
# 205                               leaf_Na_per_dry_mass
# 206                               leaf_Ni_per_dry_mass
# 207                                    leaf_P_per_area
# 208                                    leaf_P_per_area
# 209                                leaf_P_per_dry_mass
# 210                                leaf_P_per_dry_mass
# 211                                  leaf_P_resorption
# 212                                  leaf_P_resorption
# 213                                leaf_S_per_dry_mass
# 214                                leaf_S_per_dry_mass
# 215                               leaf_Se_per_dry_mass
# 216                               leaf_Si_per_dry_mass
# 217                               leaf_Zn_per_dry_mass
# 218                               leaf_Zn_per_dry_mass
# 219                                    leaf_absorption
# 220                                          leaf_area
# 221                                          leaf_area
# 222                                    leaf_area_ratio
# 223                                    leaf_area_ratio
# 224                              leaf_ash_per_dry_mass
# 225                              leaf_ash_per_dry_mass
# 226                                   leaf_capacitance
# 227                           leaf_carotenoid_per_area
# 228                       leaf_carotenoid_per_dry_mass
# 229                       leaf_carotenoid_per_dry_mass
# 230            leaf_cell_wall_N_per_cell_wall_dry_mass
# 231                        leaf_cell_wall_N_per_leaf_N
# 232                            leaf_cell_wall_fraction
# 233                        leaf_cellulose_per_dry_mass
# 234                        leaf_cellulose_per_dry_mass
# 235                         leaf_chlorophyll_A_B_ratio
# 236                         leaf_chlorophyll_A_B_ratio
# 237                        leaf_chlorophyll_A_per_area
# 238                    leaf_chlorophyll_A_per_dry_mass
# 239                        leaf_chlorophyll_B_per_area
# 240                    leaf_chlorophyll_B_per_dry_mass
# 241                      leaf_chlorophyll_content_SPAD
# 242              leaf_chlorophyll_index_modified_ND705
# 243                          leaf_chlorophyll_per_area
# 244                          leaf_chlorophyll_per_area
# 245                      leaf_chlorophyll_per_dry_mass
# 246                      leaf_chlorophyll_per_dry_mass
# 247                 leaf_chloroplast_CO2_concentration
# 248                     leaf_conductance_surface_water
# 249                  leaf_critical_temperature_maximum
# 250                  leaf_critical_temperature_maximum
# 251                  leaf_critical_temperature_minimum
# 252                     leaf_cuticle_thickness_abaxial
# 253                     leaf_cuticle_thickness_adaxial
# 254                         leaf_cuticular_conductance
# 255                         leaf_cuticular_conductance
# 256                     leaf_dark_respiration_per_area
# 257                     leaf_dark_respiration_per_area
# 258                 leaf_dark_respiration_per_dry_mass
# 259                 leaf_dark_respiration_per_dry_mass
# 260                   leaf_dark_transpiration_per_area
# 261                   leaf_dark_transpiration_per_area
# 262                                      leaf_delta13C
# 263                                      leaf_delta13C
# 264                                      leaf_delta15N
# 265                                      leaf_delta15N
# 266                                      leaf_delta18O
# 267                                       leaf_density
# 268                                       leaf_density
# 269                                      leaf_dry_mass
# 270                                      leaf_dry_mass
# 271                            leaf_dry_matter_content
# 272                            leaf_dry_matter_content
# 273                leaf_epidermal_cell_density_abaxial
# 274                leaf_epidermal_cell_density_adaxial
# 275             leaf_epidermal_cell_density_both_sides
# 276                   leaf_epidermis_Ca_per_fresh_mass
# 277                    leaf_epidermis_P_per_fresh_mass
# 278                           leaf_epidermis_thickness
# 279                   leaf_epidermis_thickness_abaxial
# 280                   leaf_epidermis_thickness_abaxial
# 281                   leaf_epidermis_thickness_adaxial
# 282                   leaf_epidermis_thickness_adaxial
# 283                       leaf_fluorescence_fv_over_fm
# 284                       leaf_fluorescence_fv_over_fm
# 285                    leaf_fluorescence_quantum_yield
# 286                    leaf_fluorescence_quantum_yield
# 287                      leaf_foliar_water_uptake_rate
# 288                                    leaf_fresh_mass
# 289                                    leaf_fresh_mass
# 290                           leaf_fresh_mass_per_area
# 291                    leaf_gas_exchange_quantum_yield
# 292                             leaf_guard_cell_length
# 293                  leaf_hypodermis_Ca_per_fresh_mass
# 294                   leaf_hypodermis_P_per_fresh_mass
# 295                  leaf_hypodermis_thickness_abaxial
# 296                  leaf_hypodermis_thickness_adaxial
# 297                    leaf_ice_nucleation_temperature
# 298                             leaf_inclination_angle
# 299                             leaf_inclination_angle
# 300                      leaf_inorganic_P_per_dry_mass
# 301                      leaf_inorganic_P_per_dry_mass
# 302                    leaf_insoluble_protein_per_area
# 303       leaf_intercellular_CO2_concentration_at_Amax
# 304       leaf_intercellular_CO2_concentration_at_Amax
# 305       leaf_intercellular_CO2_concentration_at_Asat
# 306       leaf_intercellular_CO2_concentration_at_Asat
# 307       leaf_intercellular_CO2_concentration_at_Asat
# 308  leaf_intercellular_CO2_concentration_to_atmosp...
# 309  leaf_intercellular_CO2_concentration_to_atmosp...
# 310  leaf_intercellular_CO2_concentration_to_atmosp...
# 311         leaf_internal_parenchyma_Ca_per_fresh_mass
# 312          leaf_internal_parenchyma_P_per_fresh_mass
# 313                          leaf_lamina_mass_per_area
# 314                          leaf_lamina_mass_per_area
# 315                                        leaf_length
# 316                                        leaf_length
# 317                                        leaf_length
# 318                                        leaf_length
# 319                                      leaf_lifespan
# 320                                      leaf_lifespan
# 321                    leaf_light_respiration_per_area
# 322                           leaf_lignin_per_dry_mass
# 323                           leaf_lignin_per_dry_mass
# 324                          leaf_lipid_P_per_dry_mass
# 325                          leaf_lipid_P_per_dry_mass
# 326                                 leaf_mass_fraction
# 327                                 leaf_mass_fraction
# 328                                 leaf_mass_per_area
# 329                                 leaf_mass_per_area
# 330                       leaf_mass_to_stem_mass_ratio
# 331                           leaf_maximum_temperature
# 332                           leaf_maximum_temperature
# 333                leaf_mesophyll_conductance_per_area
# 334                leaf_mesophyll_conductance_per_mass
# 335                     leaf_metabolite_P_per_dry_mass
# 336                     leaf_metabolite_P_per_dry_mass
# 337                   leaf_nucleic_acid_P_per_dry_mass
# 338                   leaf_nucleic_acid_P_per_dry_mass
# 339                          leaf_palisade_cell_length
# 340                           leaf_palisade_cell_width
# 341                         leaf_palisade_layer_number
# 342          leaf_palisade_mesophyll_Ca_per_fresh_mass
# 343           leaf_palisade_mesophyll_P_per_fresh_mass
# 344             leaf_palisade_tissue_thickness_abaxial
# 345             leaf_palisade_tissue_thickness_adaxial
# 346                           leaf_phenol_per_dry_mass
# 347                           leaf_phenol_per_dry_mass
# 348               leaf_photochemical_reflectance_index
# 349               leaf_photochemical_reflectance_index
# 350            leaf_photosynthesis_Jmax_over_Vcmax_25C
# 351                  leaf_photosynthesis_Jmax_per_area
# 352                  leaf_photosynthesis_Jmax_per_area
# 353                  leaf_photosynthesis_Jmax_per_area
# 354              leaf_photosynthesis_Jmax_per_area_25C
# 355                  leaf_photosynthesis_Jmax_per_mass
# 356                 leaf_photosynthesis_Vcmax_per_area
# 357                 leaf_photosynthesis_Vcmax_per_area
# 358                 leaf_photosynthesis_Vcmax_per_area
# 359             leaf_photosynthesis_Vcmax_per_area_25C
# 360                 leaf_photosynthesis_Vcmax_per_mass
# 361  leaf_photosynthetic_nitrogen_use_efficiency_ma...
# 362  leaf_photosynthetic_nitrogen_use_efficiency_sa...
# 363  leaf_photosynthetic_nitrogen_use_efficiency_sa...
# 364  leaf_photosynthetic_phosphorus_use_efficiency_...
# 365  leaf_photosynthetic_phosphorus_use_efficiency_...
# 366  leaf_photosynthetic_phosphorus_use_efficiency_...
# 367          leaf_photosynthetic_rate_per_area_ambient
# 368          leaf_photosynthetic_rate_per_area_ambient
# 369          leaf_photosynthetic_rate_per_area_maximum
# 370          leaf_photosynthetic_rate_per_area_maximum
# 371        leaf_photosynthetic_rate_per_area_saturated
# 372        leaf_photosynthetic_rate_per_area_saturated
# 373        leaf_photosynthetic_rate_per_area_saturated
# 374      leaf_photosynthetic_rate_per_dry_mass_maximum
# 375      leaf_photosynthetic_rate_per_dry_mass_maximum
# 376    leaf_photosynthetic_rate_per_dry_mass_saturated
# 377    leaf_photosynthetic_rate_per_dry_mass_saturated
# 378    leaf_photosynthetic_rate_per_dry_mass_saturated
# 379                               leaf_posture_numeric
# 380                                   leaf_reflectance
# 381                                   leaf_reflectance
# 382                     leaf_reflectance_near_infrared
# 383   leaf_relative_water_content_at_turgor_loss_point
# 384   leaf_relative_water_content_at_turgor_loss_point
# 385                leaf_relative_water_content_predawn
# 386                leaf_relative_water_content_predawn
# 387                       leaf_residual_P_per_dry_mass
# 388                       leaf_residual_P_per_dry_mass
# 389                    leaf_rubisco_N_per_total_leaf_N
# 390                     leaf_rubisco_per_leaf_dry_mass
# 391                leaf_sclerenchyma_Ca_per_fresh_mass
# 392                 leaf_sclerenchyma_P_per_fresh_mass
# 393                          leaf_secondary_vein_angle
# 394                      leaf_senesced_Al_per_dry_mass
# 395                       leaf_senesced_B_per_dry_mass
# 396                       leaf_senesced_C_per_dry_mass
# 397                       leaf_senesced_C_per_dry_mass
# 398                      leaf_senesced_Ca_per_dry_mass
# 399                      leaf_senesced_Ca_per_dry_mass
# 400                      leaf_senesced_Cu_per_dry_mass
# 401                      leaf_senesced_Cu_per_dry_mass
# 402                      leaf_senesced_Fe_per_dry_mass
# 403                      leaf_senesced_Fe_per_dry_mass
# 404                       leaf_senesced_K_per_dry_mass
# 405                       leaf_senesced_K_per_dry_mass
# 406                      leaf_senesced_Mg_per_dry_mass
# 407                      leaf_senesced_Mg_per_dry_mass
# 408                      leaf_senesced_Mn_per_dry_mass
# 409                      leaf_senesced_Mn_per_dry_mass
# 410                      leaf_senesced_Mo_per_dry_mass
# 411                       leaf_senesced_N_per_dry_mass
# 412                       leaf_senesced_N_per_dry_mass
# 413                      leaf_senesced_Na_per_dry_mass
# 414                      leaf_senesced_Na_per_dry_mass
# 415                       leaf_senesced_P_per_dry_mass
# 416                       leaf_senesced_P_per_dry_mass
# 417                       leaf_senesced_S_per_dry_mass
# 418                       leaf_senesced_S_per_dry_mass
# 419                      leaf_senesced_Zn_per_dry_mass
# 420                      leaf_senesced_Zn_per_dry_mass
# 421                      leaf_soluble_protein_per_area
# 422                      leaf_soluble_protein_per_area
# 423                       leaf_soluble_starch_per_area
# 424                       leaf_soluble_starch_per_area
# 425                       leaf_soluble_starch_per_mass
# 426                       leaf_soluble_starch_per_mass
# 427                       leaf_soluble_sugars_per_area
# 428                       leaf_soluble_sugars_per_area
# 429                       leaf_soluble_sugars_per_mass
# 430                       leaf_soluble_sugars_per_mass
# 431               leaf_specific_hydraulic_conductivity
# 432               leaf_specific_hydraulic_conductivity
# 433            leaf_spongy_mesophyll_Ca_per_fresh_mass
# 434             leaf_spongy_mesophyll_P_per_fresh_mass
# 435                    leaf_spongy_mesophyll_thickness
# 436                               leaf_starch_per_area
# 437         leaf_stomatal_conductance_per_area_ambient
# 438         leaf_stomatal_conductance_per_area_ambient
# 439         leaf_stomatal_conductance_per_area_ambient
# 440         leaf_stomatal_conductance_per_area_at_Amax
# 441         leaf_stomatal_conductance_per_area_at_Amax
# 442         leaf_stomatal_conductance_per_area_at_Asat
# 443         leaf_stomatal_conductance_per_area_at_Asat
# 444         leaf_stomatal_conductance_per_area_at_Asat
# 445                      leaf_stomatal_density_abaxial
# 446                      leaf_stomatal_density_abaxial
# 447                      leaf_stomatal_density_adaxial
# 448                      leaf_stomatal_density_adaxial
# 449                      leaf_stomatal_density_average
# 450                      leaf_stomatal_density_average
# 451                   leaf_stomatal_resistance_ambient
# 452                           leaf_tannin_per_dry_mass
# 453                           leaf_tannin_per_dry_mass
# 454                                     leaf_thickness
# 455                                     leaf_thickness
# 456                                     leaf_thickness
# 457                                     leaf_thickness
# 458                  leaf_thylakoid_N_per_total_leaf_N
# 459   leaf_total_non-structural_carbohydrates_per_area
# 460   leaf_total_non-structural_carbohydrates_per_mass
# 461                            leaf_total_vein_density
# 462                                  leaf_transmission
# 463                leaf_transpiration_per_area_ambient
# 464                leaf_transpiration_per_area_at_Amax
# 465                leaf_transpiration_per_area_at_Amax
# 466                leaf_transpiration_per_area_at_Asat
# 467                leaf_transpiration_per_area_at_Asat
# 468                             leaf_turgor_loss_point
# 469                             leaf_turgor_loss_point
# 470                                leaf_vein_frequency
# 471                                leaf_vessel_density
# 472                               leaf_vessel_diameter
# 473                               leaf_vessel_diameter
# 474                               leaf_vessel_diameter
# 475                         leaf_vessel_wall_thickness
# 476                              leaf_water_band_index
# 477                        leaf_water_content_per_area
# 478                        leaf_water_content_per_area
# 479                    leaf_water_content_per_dry_mass
# 480                    leaf_water_content_per_dry_mass
# 481                  leaf_water_content_per_fresh_mass
# 482                  leaf_water_content_per_fresh_mass
# 483              leaf_water_content_per_saturated_mass
# 484              leaf_water_content_per_saturated_mass
# 485   leaf_water_potential_12percent_lost_conductivity
# 486   leaf_water_potential_50percent_lost_conductivity
# 487   leaf_water_potential_88percent_lost_conductivity
# 488            leaf_water_use_efficiency_instantaneous
# 489            leaf_water_use_efficiency_instantaneous
# 490               leaf_water_use_efficiency_integrated
# 491                leaf_water_use_efficiency_intrinsic
# 492                leaf_water_use_efficiency_intrinsic
# 493                                         leaf_width
# 494                                         leaf_width
# 495                                         leaf_width
# 496                                         leaf_width
# 497                                 leaf_work_to_punch
# 498                        leaf_work_to_punch_adjusted
# 499                                 leaf_work_to_shear
# 500                                 leaf_work_to_shear
# 501                        leaf_work_to_shear_adjusted
# 502                        leaf_work_to_shear_adjusted
# 503                                  leaf_work_to_tear
# 504                         leaf_work_to_tear_adjusted
# 505                                leaf_xylem_delta15N
# 506                                       leaflet_area
# 507                                       leaflet_area
# 508                                      leaflet_count
# 509                                   leaflet_dry_mass
# 510                                   leaflet_dry_mass
# 511                                           lifespan
# 512                                           lifespan
# 513                                           lifespan
# 514                                           lifespan
# 515                                      modified_NDVI
# 516                                 modulus_of_rupture
# 517                                 modulus_of_rupture
# 518                                  osmotic_potential
# 519                   osmotic_potential_at_full_turgor
# 520                   osmotic_potential_at_full_turgor
# 521                                     petiole_length
# 522                                     petiole_length
# 523                                     petiole_length
# 524                                      petiole_width
# 525                                      petiole_width
# 526                       plant_diameter_breast_height
# 527                       plant_diameter_breast_height
# 528                                       plant_height
# 529                                       plant_height
# 530                                       plant_height
# 531                        plant_height_climbing_plant
# 532                        plant_height_climbing_plant
# 533                        plant_height_climbing_plant
# 534                          plant_height_reproductive
# 535                          plant_height_reproductive
# 536                          plant_height_reproductive
# 537                      plant_tolerance_soil_salinity
# 538                                        plant_width
# 539                                        plant_width
# 540                                        plant_width
# 541                                             ploidy
# 542               reproductive_light_environment_index
# 543                              reproductive_maturity
# 544                              reproductive_maturity
# 545                              reproductive_maturity
# 546                              reproductive_maturity
# 547                              reproductive_maturity
# 548                              reproductive_maturity
# 549                              reproductive_maturity
# 550        resprouting_capacity_proportion_individuals
# 551                    resprouting_capacity_stem_ratio
# 552                                root_C_per_dry_mass
# 553                                root_N_per_dry_mass
# 554                                root_N_per_dry_mass
# 555                                root_P_per_dry_mass
# 556                                      root_delta13C
# 557                                      root_delta15N
# 558                                      root_diameter
# 559                                      root_diameter
# 560                      root_distribution_coefficient
# 561                            root_dry_matter_content
# 562                            root_dry_matter_content
# 563                   root_fine_root_coarse_root_ratio
# 564                                 root_mass_fraction
# 565                                 root_mass_fraction
# 566                                   root_shoot_ratio
# 567                                   root_shoot_ratio
# 568                       root_soluble_starch_per_mass
# 569                       root_soluble_starch_per_mass
# 570                       root_soluble_sugars_per_mass
# 571                       root_soluble_sugars_per_mass
# 572                            root_specific_root_area
# 573                            root_specific_root_area
# 574                          root_specific_root_length
# 575                          root_specific_root_length
# 576                       root_specific_taproot_length
# 577   root_water_potential_12percent_lost_conductivity
# 578   root_water_potential_50percent_lost_conductivity
# 579   root_water_potential_88percent_lost_conductivity
# 580                                  root_wood_density
# 581                                  root_wood_density
# 582                                root_xylem_delta15N
# 583            sapwood_specific_hydraulic_conductivity
# 584            sapwood_specific_hydraulic_conductivity
# 585  sapwood_specific_hydraulic_conductivity_theore...
# 586  sapwood_specific_hydraulic_conductivity_theore...
# 587                          seed_Ca_per_seed_dry_mass
# 588                          seed_Ca_per_seed_dry_mass
# 589                           seed_K_per_seed_dry_mass
# 590                           seed_K_per_seed_dry_mass
# 591                          seed_Mg_per_seed_dry_mass
# 592                          seed_Mg_per_seed_dry_mass
# 593                           seed_N_per_seed_dry_mass
# 594                           seed_N_per_seed_dry_mass
# 595                           seed_P_per_seed_dry_mass
# 596                           seed_P_per_seed_dry_mass
# 597                           seed_S_per_seed_dry_mass
# 598                           seed_S_per_seed_dry_mass
# 599                                      seed_dry_mass
# 600                                      seed_dry_mass
# 601                              seed_dry_mass_reserve
# 602                                   seed_germination
# 603                                   seed_germination
# 604                              seed_germination_time
# 605                              seed_germination_time
# 606                              seed_germination_time
# 607                              seed_germination_time
# 608                                        seed_height
# 609                                        seed_height
# 610                                        seed_height
# 611                                        seed_height
# 612                                        seed_height
# 613                                        seed_length
# 614                                        seed_length
# 615                                        seed_length
# 616                                        seed_length
# 617                                        seed_length
# 618                         seed_oil_per_seed_dry_mass
# 619                     seed_protein_per_seed_dry_mass
# 620                                     seed_viability
# 621                                     seed_viability
# 622                                     seed_viability
# 623                                        seed_volume
# 624                                         seed_width
# 625                                         seed_width
# 626                                         seed_width
# 627                                         seed_width
# 628                                         seed_width
# 629                                 seedbank_longevity
# 630                                 seedbank_longevity
# 631                                       sprout_depth
# 632                                stem_C_per_dry_mass
# 633                                stem_C_per_dry_mass
# 634                                stem_N_per_dry_mass
# 635                                stem_N_per_dry_mass
# 636                                         stem_count
# 637                                         stem_count
# 638                     stem_dark_respiration_per_area
# 639                                      stem_delta13C
# 640                                      stem_delta15N
# 641                            stem_dry_matter_content
# 642                            stem_dry_matter_content
# 643                        stem_hydraulic_conductivity
# 644                        stem_hydraulic_conductivity
# 645                                        stem_length
# 646                                        stem_length
# 647                                        stem_length
# 648                                 stem_mass_fraction
# 649                                 stem_mass_fraction
# 650                      stem_mass_to_shoot_mass_ratio
# 651                         stem_modulus_of_elasticity
# 652                         stem_modulus_of_elasticity
# 653          stem_saturated_water_content_per_dry_mass
# 654                       stem_soluble_starch_per_mass
# 655                       stem_soluble_starch_per_mass
# 656                       stem_soluble_sugars_per_mass
# 657               stem_specific_hydraulic_conductivity
# 658               stem_specific_hydraulic_conductivity
# 659                                stem_vessel_density
# 660                                stem_vessel_density
# 661                               stem_vessel_diameter
# 662                               stem_vessel_diameter
# 663                               stem_vessel_diameter
# 664                     stem_vessel_diameter_hydraulic
# 665                     stem_vessel_diameter_hydraulic
# 666                         stem_vessel_lumen_fraction
# 667                         stem_vessel_lumen_fraction
# 668                      stem_vessel_multiple_fraction
# 669                     stem_vessel_non_lumen_fraction
# 670                          stem_vessel_wall_fraction
# 671                          stem_vessel_wall_fraction
# 672                         stem_vessel_wall_thickness
# 673              stem_water_content_per_saturated_mass
# 674              stem_water_content_per_saturated_mass
# 675                                stem_water_delta18O
# 676   stem_water_potential_12percent_lost_conductivity
# 677   stem_water_potential_12percent_lost_conductivity
# 678   stem_water_potential_50percent_lost_conductivity
# 679   stem_water_potential_50percent_lost_conductivity
# 680   stem_water_potential_88percent_lost_conductivity
# 681   stem_water_potential_88percent_lost_conductivity
# 682                     stem_xylem_vulnerability_index
# 683                     stem_xylem_vulnerability_index
# 684                             storage_organ_diameter
# 685                             storage_organ_diameter
# 686                             storage_organ_diameter
# 687                               storage_organ_length
# 688                               storage_organ_length
# 689                               storage_organ_length
# 690                             water_potential_midday
# 691                             water_potential_midday
# 692                             water_potential_midday
# 693                            water_potential_predawn
# 694                            water_potential_predawn
# 695                                wood_C_per_dry_mass
# 696                                wood_C_per_dry_mass
# 697                               wood_Ca_per_dry_mass
# 698                               wood_Ca_per_dry_mass
# 699                                wood_K_per_dry_mass
# 700                                wood_K_per_dry_mass
# 701                               wood_Mg_per_dry_mass
# 702                               wood_Mg_per_dry_mass
# 703                                wood_N_per_dry_mass
# 704                                wood_N_per_dry_mass
# 705                               wood_Na_per_dry_mass
# 706                               wood_Na_per_dry_mass
# 707                                wood_P_per_dry_mass
# 708                                wood_P_per_dry_mass
# 709                     wood_axial_parenchyma_fraction
# 710                     wood_axial_parenchyma_fraction
# 711                              wood_conduit_fraction
# 712                              wood_conduit_fraction
# 713                          wood_dead_Ca_per_dry_mass
# 714                          wood_dead_Ca_per_dry_mass
# 715                           wood_dead_K_per_dry_mass
# 716                           wood_dead_K_per_dry_mass
# 717                          wood_dead_Mg_per_dry_mass
# 718                          wood_dead_Mg_per_dry_mass
# 719                           wood_dead_N_per_dry_mass
# 720                           wood_dead_N_per_dry_mass
# 721                          wood_dead_Na_per_dry_mass
# 722                          wood_dead_Na_per_dry_mass
# 723                           wood_dead_P_per_dry_mass
# 724                           wood_dead_P_per_dry_mass
# 725                                      wood_delta13C
# 726                                      wood_delta15N
# 727                                       wood_density
# 728                                       wood_density
# 729                                wood_fibre_fraction
# 730                                wood_fibre_fraction
# 731                       wood_ray_parenchyma_fraction
# 732                       wood_ray_parenchyma_fraction
# 733                             wood_tracheid_fraction
# 734                        xylem_modulus_of_elasticity
# 735                        xylem_modulus_of_elasticity
# 736                           xylem_to_leaf_area_ratio
#
#                                       unit value_type  Counts
# 0                                    mg/mg       mean      47
# 1                                       mg       mean      47
# 2                            umol{CO2}/mol        raw     840
# 3                                     mg/g        raw      70
# 4                                     mg/g        raw      70
# 5                                     mg/g        raw     229
# 6                                     mg/g       mean      34
# 7                                     mg/g        raw      70
# 8                                     mg/g        raw      70
# 9                                     mg/g        raw      70
# 10                                    mg/g       mean      34
# 11                                    mg/g        raw      70
# 12                                    mg/g       mean      34
# 13                                    mg/g        raw      70
# 14                                    mg/g        raw      70
# 15                                    mg/g       mean      33
# 16                                    mg/g        raw     380
# 17                                    mg/g       mean      25
# 18                                    mg/g        raw      70
# 19                                    mg/g       mean      34
# 20                                    mg/g        raw     221
# 21                                    mg/g        raw      70
# 22                                    mg/g        raw      69
# 23                                     g/g        raw      63
# 24                                   mg/mg        raw      70
# 25                           {delta}[ppth]        raw     159
# 26                           {delta}[ppth]        raw     159
# 27                                  mg/mm3       mean      62
# 28                                  mg/mm3        raw     205
# 29                                   g/cm2       mean      27
# 30                                   mg/mg        raw      70
# 31                                     MPa       mean      62
# 32                                     MPa        raw     130
# 33                                   mg/mg        raw      70
# 34                                      mm       mean    1028
# 35                                      mm        raw    2175
# 36                                   mm/mm       mean     914
# 37                                   mm/mm        raw    1015
# 38                                     g/g        raw      19
# 39                                     g/g       mean      64
# 40                                   mg/mg       mean      45
# 41                                     mm2       mean      58
# 42                                      mm       mean      33
# 43                                      cm    maximum     755
# 44                                      cm    minimum     799
# 45                                      cm    maximum     740
# 46                                      cm    minimum     799
# 47                         {count}/{count}    maximum     806
# 48                         {count}/{count}    minimum     806
# 49                                     MPa       mean     125
# 50                                     MPa        raw     303
# 51                                     um2       mean      38
# 52                                      mg       mean     314
# 53                         {dimensionless}       mean     199
# 54                                       s        raw    1061
# 55                                   g/cm3        raw     145
# 56                                     g/g        raw      98
# 57                                    cm/s        raw     145
# 58                                       s        raw    1063
# 59                                      mo        bin     537
# 60                                      mo    maximum      65
# 61                                      mo       mean      65
# 62                                      mo     median     103
# 63                                      mo    minimum      75
# 64                                      mo       mean       4
# 65                                      mo    minimum       3
# 66                                      mo        bin     174
# 67                                      mo    maximum     276
# 68                                      mo       mean    1501
# 69                                      mo    minimum    2110
# 70                                      mo       mode     180
# 71                                      mo       mode      36
# 72                                      mo    maximum       4
# 73                                      mo       mean      27
# 74                                      mo    minimum     603
# 75                                      mo       mode       1
# 76                                      mo    maximum      58
# 77                                      mo       mean      41
# 78                                      mo    minimum      82
# 79                                      mo       mode      25
# ...
# 487                                    MPa       mean      73
# 488                    umol{CO2}/mmol{H2O}       mean    1103
# 489                    umol{CO2}/mmol{H2O}        raw    1760
# 490                      g{biomass}/g{H2O}        raw     116
# 491                    umol{CO2}/mmol{H2O}       mean     207
# 492                    umol{CO2}/mmol{H2O}        raw     481
# 493                                     mm    maximum   36218
# 494                                     mm       mean    2696
# 495                                     mm    minimum   33528
# 496                                     mm        raw    1891
# 497                                    N/m       mean    1991
# 498                                   N/m2       mean    1991
# 499                                      N       mean     192
# 500                                      N        raw      48
# 501                                    N/m       mean     192
# 502                                    N/m        raw      48
# 503                                      N       mean      16
# 504                                    N/m       mean      36
# 505                          {delta}[ppth]        raw      78
# 506                                    mm2       mean     276
# 507                                    mm2        raw     412
# 508                                {count}       mode     305
# 509                                     mg       mean      10
# 510                                     mg        raw     410
# 511                                      a        bin    9862
# 512                                      a    maximum     692
# 513                                      a       mean       2
# 514                                      a    minimum     890
# 515                        {dimensionless}        raw     453
# 516                                    MPa       mean     187
# 517                                    MPa        raw     295
# 518                                    MPa        raw      80
# 519                                    MPa       mean     121
# 520                                    MPa        raw     393
# 521                                     cm    maximum    8381
# 522                                     cm       mean       1
# 523                                     cm    minimum    7133
# 524                                     cm    maximum     117
# 525                                     cm    minimum     112
# 526                                     mm    maximum     706
# 527                                     mm    minimum       1
# 528                                      m    maximum   52096
# 529                                      m       mean     115
# 530                                      m    minimum   17505
# 531                                      m    maximum       4
# 532                                      m       mean       8
# 533                                      m    minimum       4
# 534                                      m    maximum      61
# 535                                      m       mean      49
# 536                                      m    minimum      61
# 537                                   dS/m       mean      99
# 538                                      m    maximum      85
# 539                                      m       mean      17
# 540                                      m    minimum      11
# 541                                {count}       mean      61
# 542                        {dimensionless}       mean     207
# 543                                      a        bin   10180
# 544                                      a    maximum     416
# 545                                      a       mean     485
# 546                                      a     median      99
# 547                                      a    minimum    1523
# 548                                      a       mode     245
# 549                                      a        raw     249
# 550                        {count}/{count}       mean     438
# 551                        {count}/{count}       mean     780
# 552                                   mg/g        raw     132
# 553                                   mg/g       mean       9
# 554                                   mg/g        raw     132
# 555                                   mg/g       mean       9
# 556                          {delta}[ppth]        raw     132
# 557                          {delta}[ppth]        raw     131
# 558                                     mm    maximum     264
# 559                                     mm       mean      37
# 560                        {dimensionless}       mean      75
# 561                                   mg/g       mean      83
# 562                                   mg/g        raw      41
# 563                                mm3/mm3        raw      41
# 564                                  mg/mg       mean      11
# 565                                  mg/mg        raw    2163
# 566                     mg{root}/mg{shoot}       mean      32
# 567                     mg{root}/mg{shoot}        raw    2276
# 568                                   mg/g       mean      83
# 569                                   mg/g        raw      43
# 570                                   mg/g       mean      66
# 571                                   mg/g        raw      43
# 572                                 mm2/mg       mean      61
# 573                                 mm2/mg        raw      41
# 574                                    m/g       mean      22
# 575                                    m/g        raw     241
# 576                                    m/g        raw     188
# 577                                    MPa       mean       3
# 578                                    MPa       mean       3
# 579                                    MPa       mean       3
# 580                                 mg/mm3       mean      90
# 581                                 mg/mm3        raw     115
# 582                          {delta}[ppth]        raw      67
# 583                             kg/m/MPa/s       mean     195
# 584                             kg/m/MPa/s        raw     372
# 585                             kg/m/MPa/s       mean      27
# 586                             kg/m/MPa/s        raw     267
# 587                                   mg/g       mean      21
# 588                                   mg/g        raw       6
# 589                                   mg/g       mean      41
# 590                                   mg/g        raw       6
# 591                                   mg/g       mean      21
# 592                                   mg/g        raw       6
# 593                                   mg/g       mean      41
# 594                                   mg/g        raw       6
# 595                                   mg/g       mean      46
# 596                                   mg/g        raw      42
# 597                                   mg/g       mean      21
# 598                                   mg/g        raw       2
# 599                                     mg       mean   22104
# 600                                     mg        raw   18319
# 601                                     mg       mean     104
# 602                        {count}/{count}    maximum       8
# 603                        {count}/{count}       mean    8644
# 604                                      d    maximum    1824
# 605                                      d       mean    2639
# 606                                      d     median      67
# 607                                      d    minimum    2109
# 608                                     mm    maximum    1454
# 609                                     mm       mean     464
# 610                                     mm     median       1
# 611                                     mm    minimum     826
# 612                                     mm        raw    2574
# 613                                     mm    maximum   13717
# 614                                     mm       mean    2220
# 615                                     mm     median       2
# 616                                     mm    minimum   10772
# 617                                     mm        raw    2574
# 618                                    g/g       mean     327
# 619                                    g/g       mean     145
# 620                        {count}/{count}    maximum       1
# 621                        {count}/{count}       mean     161
# 622                        {count}/{count}    minimum       1
# 623                                    mm3       mean     516
# 624                                     mm    maximum    5316
# 625                                     mm       mean    2762
# 626                                     mm     median       1
# 627                                     mm    minimum    4453
# 628                                     mm        raw    2574
# 629                                      a        bin   10533
# 630                                      a       mean      14
# 631                                     mm        raw    4349
# 632                                   mg/g       mean      82
# 633                                   mg/g        raw      71
# 634                                   mg/g       mean      84
# 635                                   mg/g        raw      73
# 636                                {count}       mean      44
# 637                                {count}        raw      96
# 638                         umol{CO2}/m2/s       mean     212
# 639                          {delta}[ppth]        raw      71
# 640                          {delta}[ppth]        raw      71
# 641                                   mg/g       mean      86
# 642                                   mg/g        raw     160
# 643                        10^6.kg.m/MPa/s       mean       7
# 644                        10^6.kg.m/MPa/s        raw     257
# 645                                      m    maximum      21
# 646                                      m       mean      34
# 647                                      m    minimum      20
# 648                                    g/g       mean      18
# 649                                    g/g        raw    1269
# 650                                    g/g        raw     558
# 651                                    MPa       mean      62
# 652                                    MPa        raw     160
# 653                                    g/g        raw     119
# 654                                   mg/g       mean      66
# 655                                   mg/g        raw      43
# 656                                   mg/g        raw      43
# 657                             kg/m/MPa/s       mean       3
# 658                             kg/m/MPa/s        raw     185
# 659                            {count}/mm2       mean     366
# 660                            {count}/mm2        raw     673
# 661                                     um    maximum     234
# 662                                     um       mean     529
# 663                                     um        raw     442
# 664                                     um       mean     235
# 665                                     um        raw     515
# 666                                mm2/mm2       mean     209
# 667                                mm2/mm2        raw     680
# 668                        {dimensionless}        raw      90
# 669                                mm2/mm2        raw      19
# 670                                mm2/mm2       mean       9
# 671                                mm2/mm2        raw     278
# 672                                     um       mean       7
# 673                                    g/g       mean      64
# 674                                    g/g        raw      73
# 675                          {delta}[ppth]        raw      95
# 676                                    MPa       mean      21
# 677                                    MPa        raw      21
# 678                                    MPa       mean      84
# 679                                    MPa        raw      92
# 680                                    MPa       mean      68
# 681                                    MPa        raw      21
# 682                          um.m2/{count}       mean       7
# 683                          um.m2/{count}        raw      90
# 684                                     mm    maximum       6
# 685                                     mm       mean       8
# 686                                     mm    minimum       6
# 687                                     mm    maximum       6
# 688                                     mm       mean       7
# 689                                     mm    minimum       7
# 690                                    MPa       mean     499
# 691                                    MPa    minimum      24
# 692                                    MPa        raw     480
# 693                                    MPa       mean     467
# 694                                    MPa        raw     586
# 695                                   mg/g       mean       6
# 696                                   mg/g        raw     265
# 697                                   mg/g       mean      41
# 698                                   mg/g        raw       2
# 699                                   mg/g       mean      41
# 700                                   mg/g        raw       2
# 701                                   mg/g       mean      38
# 702                                   mg/g        raw       2
# 703                                   mg/g       mean      46
# 704                                   mg/g        raw     493
# 705                                   mg/g       mean      24
# 706                                   mg/g        raw       2
# 707                                   mg/g       mean      51
# 708                                   mg/g        raw     228
# 709                                mm2/mm2       mean       9
# 710                                mm2/mm2        raw     425
# 711                                mm2/mm2       mean       9
# 712                                mm2/mm2        raw     147
# 713                                   mg/g       mean       7
# 714                                   mg/g        raw       2
# 715                                   mg/g       mean       7
# 716                                   mg/g        raw       2
# 717                                   mg/g       mean       7
# 718                                   mg/g        raw       2
# 719                                   mg/g       mean       7
# 720                                   mg/g        raw       2
# 721                                   mg/g       mean       6
# 722                                   mg/g        raw       1
# 723                                   mg/g       mean       7
# 724                                   mg/g        raw       2
# 725                          {delta}[ppth]        raw     265
# 726                          {delta}[ppth]        raw     265
# 727                                 mg/mm3       mean    2790
# 728                                 mg/mm3        raw   10290
# 729                                mm2/mm2       mean      30
# 730                                mm2/mm2        raw     541
# 731                                mm2/mm2       mean       9
# 732                                mm2/mm2        raw     425
# 733                                mm2/mm2        raw      72
# 734                                    MPa       mean     187
# 735                                    MPa        raw     497
# 736                   cm2{xylem}/mm2{leaf}       mean      21

# %% [markdown]
# ## 3.2. Selected Traits
# * Traits have been selected for this list based on ease of field based measurement.
#   * For example, a ruler can easily be used in the field to measure leaf width.
# * Initial selection of traits were then verified by cross referencing definitions.yml and, if more clarification is required, methods.csv.
# * Example exlcusions:
#   * leaf_lifespan - requires observation over time
#   * fruit_dry_weight - requires drying of the fruit
#   * leaf_mass_per_area - requires several measurements to calculate
#   * leaf_palisade_tissue_thickness_abaxial - measured in um
#   * root_diameter - requires excavation
#   * root_wood_density - requires more complex measurements
# * Will there be sufficient data points to sufficiently represent each feature for ML?
#   * For example, a trait may exist for most species, but there could be just one average value entered per species.
#     * There may at least be sufficient data points if rolled up for genus or family.

# %%
selected_traits_initial = [
                           'bark_thickness',
                           'bark_thickness_index',
                           'branch_terminal_twig_cross_sectional_area',
                           'branch_terminal_twig_length',
                           'bud_length',
                           'buds_per_inflorescence',
                           'flower_androecium_structural_merism',
                           'flower_androecium_structural_whorls_count',
                           'flower_count_maximum',
                           'flower_diameter',
                           'flower_fertile_stamens_count',
                           'flower_filament_fusion',
                           'flower_filament_fusion_to_inner_perianth',
                           'flower_length',
                           'flower_ovary_fusion',
                           'flower_ovules_per_functional_carpel_count',
                           'flower_perianth_fusion',
                           'flower_perianth_merism',
                           'flower_perianth_parts_count',
                           'flower_perianth_whorls_count',
                           'flower_pollen_apertures_count',
                           'flower_pollen_length',
                           'flower_structural_carpels_count',
                           'flower_style_fusion',
                           'fruit_height',
                           'fruit_length',
                           'fruit_wall_thickness',
                           'fruit_width',
                           'leaf_area',
                           'leaf_inclination_angle',
                           'leaf_length',
                           'leaf_posture_numeric',
                           'leaf_secondary_vein_angle',
                           'leaf_thickness',
                           'leaf_vein_frequency',
                           'leaf_vessel_density',
                           'leaf_width',
                           'leaflet_area',
                           'leaflet_count',
                           'petiole_length',
                           'petiole_width',
                           'plant_diameter_breast_height',
                           'plant_height',
                           'plant_height_climbing_plant',
                           'plant_height_reproductive',
                           'plant_width',
                           'ploidy',
                           'resprouting_capacity_proportion_individuals',
                           'resprouting_capacity_stem_ratio',
                           'seed_germination',
                           'sprout_depth',
                           'stem_count',
                           'stem_length',
                           'storage_organ_diameter',
                           'storage_organ_length'
                           ]

# %% [markdown]
# ### Notes:
# * **bark_thickness** and **bark_thickness_index**
#   * definitions.yml: bark_thickness_index: Ratio of two times bark thickness to stem diamter.
#   * Drop **bark_thickness**, as it may be arbitrary on its own.
# * **branch_terminal_twig_cross_sectional_area**
#   * Could be approximated by measuring the largest width, and the width perpedicular to that.
# * flower and fruit measurements
#   * These measurements depend on the plant being in the state of flowering and producing fruit, respectively.
# * **leaf_vein_frequency** and **leaf_vessel_density**
#   * The former appears achievable in the field while the latter requires more complex instruments, like a microscope and is excluded.
# * **leaflet_area**
#   * A small scanner could be used for quick area calculation in the field, or simpler techniques to estimate.
# * **plant_diameter_breast_height**
#   * A somewhat obscure method of measurement as it geenrally pertains to plant diameter 1.4m above ground. It is excluded.
# * **ploidy**
#   * Chromosome detail, so it is excluded.
# * **resprouting_capacity_proportion_individuals** and **resprouting_capacity_stem_ratio**
#   * Fire response metric, so they are excluded.
# * **seed_germination**
#   * Germination under specified conditions, so it is excluded.
# * **sprout_depth**
#   * Fire response metric, so it is excluded.
# * **storage_organ_diameter** and **storage_organ_length**
#   * Includes below ground, so they are excluded.

# %% [markdown]
# ### Selected traits, round 2:

# %%
selected_traits2 = [
                   'bark_thickness',
                   'bark_thickness_index',
                   'branch_terminal_twig_cross_sectional_area',
                   'branch_terminal_twig_length',
                   'bud_length',
                   'buds_per_inflorescence',
                   'flower_androecium_structural_merism',
                   'flower_androecium_structural_whorls_count',
                   'flower_count_maximum',
                   'flower_diameter',
                   'flower_fertile_stamens_count',
                   'flower_filament_fusion',
                   'flower_filament_fusion_to_inner_perianth',
                   'flower_length',
                   'flower_ovary_fusion',
                   'flower_ovules_per_functional_carpel_count',
                   'flower_perianth_fusion',
                   'flower_perianth_merism',
                   'flower_perianth_parts_count',
                   'flower_perianth_whorls_count',
                   'flower_pollen_apertures_count',
                   'flower_pollen_length',
                   'flower_structural_carpels_count',
                   'flower_style_fusion',
                   'fruit_height',
                   'fruit_length',
                   'fruit_wall_thickness',
                   'fruit_width',
                   'leaf_area',
                   'leaf_inclination_angle',
                   'leaf_length',
                   'leaf_posture_numeric',
                   'leaf_secondary_vein_angle',
                   'leaf_thickness',
                   'leaf_vein_frequency',
                   'leaf_width',
                   'leaflet_area',
                   'leaflet_count',
                   'petiole_length',
                   'petiole_width',
                   'plant_height',
                   'plant_height_climbing_plant',
                   'plant_height_reproductive',
                   'plant_width',
                   'stem_count',
                   'stem_length'
                   ]
print(f'Total traits selected: {len(selected_traits2)}')
# Out:
# Total traits selected: 46

# %% [markdown]
# ## 3.3. Sample Counts of Selected Traits Round 2

# %%
sample_counts2_df = traits_grouped_df[traits_grouped_df['trait_name'].isin(selected_traits2)].sort_values(by=['Counts'], ascending=[False])
sample_counts2_df
# Out:
#                                     trait_name             unit value_type  \
# 528                               plant_height                m    maximum
# 315                                leaf_length               mm    maximum
# 317                                leaf_length               mm    minimum
# 493                                 leaf_width               mm    maximum
# 495                                 leaf_width               mm    minimum
# 153                               fruit_length               mm    maximum
# 530                               plant_height                m    minimum
# 155                               fruit_length               mm    minimum
# 221                                  leaf_area              mm2        raw
# 158                                fruit_width               mm    maximum
# 160                                fruit_width               mm    minimum
# 220                                  leaf_area              mm2       mean
# 521                             petiole_length               cm    maximum
# 523                             petiole_length               cm    minimum
# 150                               fruit_height               mm    maximum
# 152                               fruit_height               mm    minimum
# 457                             leaf_thickness               mm        raw
# 455                             leaf_thickness               mm       mean
# 494                                 leaf_width               mm       mean
# 35                              bark_thickness               mm        raw
# 318                                leaf_length               mm        raw
# 496                                 leaf_width               mm        raw
# 316                                leaf_length               mm       mean
# 120                flower_perianth_parts_count          {count}       mode
# 123               flower_perianth_whorls_count          {count}       mode
# 299                     leaf_inclination_angle              deg        raw
# 117                     flower_perianth_merism          {count}       mode
# 96                flower_fertile_stamens_count          {count}       mode
# 157                       fruit_wall_thickness               mm        raw
# 34                              bark_thickness               mm       mean
# 37                        bark_thickness_index            mm/mm        raw
# 36                        bark_thickness_index            mm/mm       mean
# 132            flower_structural_carpels_count          {count}       mode
# 114                     flower_perianth_fusion  {dimensionless}       mode
# 48                      buds_per_inflorescence  {count}/{count}    minimum
# 47                      buds_per_inflorescence  {count}/{count}    maximum
# 44                                  bud_length               cm    minimum
# 43                                  bud_length               cm    maximum
# 99                      flower_filament_fusion  {dimensionless}       mode
# 89   flower_androecium_structural_whorls_count          {count}       mode
# 111  flower_ovules_per_functional_carpel_count          {count}       mode
# 86         flower_androecium_structural_merism          {count}       mode
# 102   flower_filament_fusion_to_inner_perianth  {dimensionless}       mode
# 95                flower_fertile_stamens_count          {count}    minimum
# 94                flower_fertile_stamens_count          {count}    maximum
# 113                     flower_perianth_fusion  {dimensionless}    minimum
# 112                     flower_perianth_fusion  {dimensionless}    maximum
# 507                               leaflet_area              mm2        raw
# 154                               fruit_length               mm       mean
# 126              flower_pollen_apertures_count          {count}       mode
# 108                        flower_ovary_fusion  {dimensionless}       mode
# 129                       flower_pollen_length               um    minimum
# 127                       flower_pollen_length               um    maximum
# 161                                fruit_width               mm        raw
# 156                               fruit_length               mm        raw
# 118                flower_perianth_parts_count          {count}    maximum
# 119                flower_perianth_parts_count          {count}    minimum
# 159                                fruit_width               mm       mean
# 508                              leaflet_count          {count}       mode
# 393                  leaf_secondary_vein_angle              deg       mean
# 131            flower_structural_carpels_count          {count}    minimum
# 135                        flower_style_fusion  {dimensionless}       mode
# 130            flower_structural_carpels_count          {count}    maximum
# 93                             flower_diameter               cm    minimum
# 91                             flower_diameter               cm    maximum
# 506                               leaflet_area              mm2       mean
# 470                        leaf_vein_frequency       {count}/mm       mean
# 116                     flower_perianth_merism          {count}    minimum
# 115                     flower_perianth_merism          {count}    maximum
# 110  flower_ovules_per_functional_carpel_count          {count}    minimum
# 109  flower_ovules_per_functional_carpel_count          {count}    maximum
# 103                              flower_length               cm    maximum
# 105                              flower_length               cm    minimum
# 379                       leaf_posture_numeric               mm        raw
# 92                             flower_diameter               cm       mean
# 524                              petiole_width               cm    maximum
# 529                               plant_height                m       mean
# 525                              petiole_width               cm    minimum
# 637                                 stem_count          {count}        raw
# 298                     leaf_inclination_angle              deg       mean
# 538                                plant_width                m    maximum
# 97                      flower_filament_fusion  {dimensionless}    maximum
# 98                      flower_filament_fusion  {dimensionless}    minimum
# 84         flower_androecium_structural_merism          {count}    maximum
# 85         flower_androecium_structural_merism          {count}    minimum
# 104                              flower_length               cm       mean
# 534                  plant_height_reproductive                m    maximum
# 536                  plant_height_reproductive                m    minimum
# 41   branch_terminal_twig_cross_sectional_area              mm2       mean
# 125              flower_pollen_apertures_count          {count}    minimum
# 124              flower_pollen_apertures_count          {count}    maximum
# 535                  plant_height_reproductive                m       mean
# 636                                 stem_count          {count}       mean
# 101   flower_filament_fusion_to_inner_perianth  {dimensionless}    minimum
# 100   flower_filament_fusion_to_inner_perianth  {dimensionless}    maximum
# 646                                stem_length                m       mean
# 42                 branch_terminal_twig_length               mm       mean
# 645                                stem_length                m    maximum
# 133                        flower_style_fusion  {dimensionless}    maximum
# 134                        flower_style_fusion  {dimensionless}    minimum
# 647                                stem_length                m    minimum
# 539                                plant_width                m       mean
# 87   flower_androecium_structural_whorls_count          {count}    maximum
# 88   flower_androecium_structural_whorls_count          {count}    minimum
# 122               flower_perianth_whorls_count          {count}    minimum
# 121               flower_perianth_whorls_count          {count}    maximum
# 540                                plant_width                m    minimum
# 128                       flower_pollen_length               um       mean
# 532                plant_height_climbing_plant                m       mean
# 90                        flower_count_maximum          {count}       mean
# 107                        flower_ovary_fusion  {dimensionless}    minimum
# 106                        flower_ovary_fusion  {dimensionless}    maximum
# 533                plant_height_climbing_plant                m    minimum
# 531                plant_height_climbing_plant                m    maximum
# 454                             leaf_thickness               mm    maximum
# 151                               fruit_height               mm       mean
# 522                             petiole_length               cm       mean
# 456                             leaf_thickness               mm    minimum
#
#      Counts
# 528   52096
# 315   41517
# 317   37367
# 493   36218
# 495   33528
# 153   21289
# 530   17505
# 155   17320
# 221   13768
# 158   13556
# 160   12101
# 220   11821
# 521    8381
# 523    7133
# 150    4449
# 152    3687
# 457    3495
# 455    2873
# 494    2696
# 35     2175
# 318    1951
# 496    1891
# 316    1730
# 120    1590
# 123    1553
# 299    1438
# 117    1433
# 96     1398
# 157    1029
# 34     1028
# 37     1015
# 36      914
# 132     853
# 114     818
# 48      806
# 47      806
# 44      799
# 43      755
# 99      641
# 89      608
# 111     554
# 86      526
# 102     516
# 95      465
# 94      465
# 113     448
# 112     448
# 507     412
# 154     400
# 126     399
# 108     364
# 129     346
# 127     346
# 161     336
# 156     336
# 118     324
# 119     324
# 159     321
# 508     305
# 393     287
# 131     280
# 135     279
# 130     278
# 93      277
# 91      277
# 506     276
# 470     254
# 116     251
# 115     251
# 110     233
# 109     233
# 103     170
# 105     170
# 379     144
# 92      136
# 524     117
# 529     115
# 525     112
# 637      96
# 298      94
# 538      85
# 97       79
# 98       79
# 84       77
# 85       77
# 104      66
# 534      61
# 536      61
# 41       58
# 125      49
# 124      49
# 535      49
# 636      44
# 101      40
# 100      40
# 646      34
# 42       33
# 645      21
# 133      20
# 134      20
# 647      20
# 539      17
# 87       15
# 88       15
# 122      14
# 121      14
# 540      11
# 128       9
# 532       8
# 90        7
# 107       4
# 106       4
# 533       4
# 531       4
# 454       1
# 151       1
# 522       1
# 456       1

# %%
print(f'Sample count minimum: {sample_counts2_df.Counts.min()}, Sample count maximum: {sample_counts2_df.Counts.max()}')
# Out:
# Sample count minimum: 1, Sample count maximum: 52096

# %% [markdown]
# ### Notes
# * The majority of features appear to have too few samples to provide value to the model.

# %% [markdown]
# ## 3.4. Taxa Counts
# * It would be worth considering the possible class count with respect to the number of entries per feature.
# * Firstly, preview of som taxa.csv data:

# %%
taxa_csv = 'austraits-7.0.0/taxa.csv'
taxa_df = pd.read_csv(taxa_csv, encoding='ISO-8859-1', low_memory=False)
taxa_df.head(10)
# Out:
#                                           taxon_name  taxon_rank  \
# 0  (Dockrillia pugioniformis x Dockrillia striola...     species
# 1                               Abelia x grandiflora     species
# 2                              Abelmoschus ficulneus     species
# 3                                Abelmoschus manihot     species
# 4                 Abelmoschus manihot subsp. manihot  subspecies
# 5            Abelmoschus manihot subsp. tetraphyllus  subspecies
# 6                              Abelmoschus moschatus     species
# 7             Abelmoschus moschatus subsp. biakensis  subspecies
# 8             Abelmoschus moschatus subsp. moschatus  subspecies
# 9             Abelmoschus moschatus subsp. tuberosus  subspecies
#
#   taxonomic_status taxonomic_dataset taxon_name_alternatives        genus  \
# 0         accepted               APC                     NaN  (Dockrillia
# 1         accepted               APC                     NaN       Abelia
# 2         accepted               APC                     NaN  Abelmoschus
# 3         accepted               APC                     NaN  Abelmoschus
# 4         accepted               APC                     NaN  Abelmoschus
# 5         accepted               APC                     NaN  Abelmoschus
# 6         accepted               APC                     NaN  Abelmoschus
# 7         accepted               APC                     NaN  Abelmoschus
# 8         accepted               APC                     NaN  Abelmoschus
# 9         accepted               APC                     NaN  Abelmoschus
#
#            family                                           binomial  \
# 0     Orchidaceae  (Dockrillia pugioniformis x Dockrillia striola...
# 1  Caprifoliaceae                               Abelia x grandiflora
# 2       Malvaceae                              Abelmoschus ficulneus
# 3       Malvaceae                                Abelmoschus manihot
# 4       Malvaceae                                Abelmoschus manihot
# 5       Malvaceae                                Abelmoschus manihot
# 6       Malvaceae                              Abelmoschus moschatus
# 7       Malvaceae                              Abelmoschus moschatus
# 8       Malvaceae                              Abelmoschus moschatus
# 9       Malvaceae                              Abelmoschus moschatus
#
#                                  trinomial  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4       Abelmoschus manihot subsp. manihot
# 5  Abelmoschus manihot subsp. tetraphyllus
# 6                                      NaN
# 7   Abelmoschus moschatus subsp. biakensis
# 8   Abelmoschus moschatus subsp. moschatus
# 9   Abelmoschus moschatus subsp. tuberosus
#
#                                   taxon_distribution     establishment_means  \
# 0                                                NSW                  native
# 1                                  NSW (naturalised)             naturalised
# 2                                        WA, NT, Qld                  native
# 3  ChI, NT, Qld (naturalised), NSW (doubtfully na...  native and naturalised
# 4    Qld (naturalised), NSW (doubtfully naturalised)             naturalised
# 5                             ChI, Qld (naturalised)  native and naturalised
# 6                     WA, NT, Qld, NSW (naturalised)  native and naturalised
# 7                                                 WA                  native
# 8                                  NSW (naturalised)             naturalised
# 9                                        WA, NT, Qld                  native
#
#                                      scientific_name  \
# 0  (Dockrillia pugioniformis (A.Cunn.) Rauschert ...
# 1    Abelia x grandiflora (Rovelli ex AndrÃ©) Rehder
# 2                   Abelmoschus ficulneus (L.) Wight
# 3                    Abelmoschus manihot (L.) Medik.
# 4     Abelmoschus manihot (L.) Medik. subsp. manihot
# 5  Abelmoschus manihot subsp. tetraphyllus (Roxb....
# 6                       Abelmoschus moschatus Medik.
# 7  Abelmoschus moschatus subsp. biakensis (Hochr....
# 8      Abelmoschus moschatus Medik. subsp. moschatus
# 9  Abelmoschus moschatus subsp. tuberosus (Span.)...
#
#                                             taxon_id  \
# 0  https://id.biodiversity.org.au/taxon/apni/5140...
# 1  https://id.biodiversity.org.au/taxon/apni/5143...
# 2   https://id.biodiversity.org.au/node/apni/2897916
# 3   https://id.biodiversity.org.au/node/apni/2901085
# 4   https://id.biodiversity.org.au/node/apni/2917035
# 5   https://id.biodiversity.org.au/node/apni/2892917
# 6   https://id.biodiversity.org.au/node/apni/2900572
# 7   https://id.biodiversity.org.au/node/apni/2907435
# 8   https://id.biodiversity.org.au/node/apni/2911283
# 9   https://id.biodiversity.org.au/node/apni/2919287
#
#                                       taxon_id_genus  \
# 0  https://id.biodiversity.org.au/taxon/apni/5179...
# 1  https://id.biodiversity.org.au/taxon/apni/5143...
# 2   https://id.biodiversity.org.au/node/apni/2898872
# 3   https://id.biodiversity.org.au/node/apni/2898872
# 4   https://id.biodiversity.org.au/node/apni/2898872
# 5   https://id.biodiversity.org.au/node/apni/2898872
# 6   https://id.biodiversity.org.au/node/apni/2898872
# 7   https://id.biodiversity.org.au/node/apni/2898872
# 8   https://id.biodiversity.org.au/node/apni/2898872
# 9   https://id.biodiversity.org.au/node/apni/2898872
#
#                                      taxon_id_family  \
# 0  https://id.biodiversity.org.au/taxon/apni/5179...
# 1  https://id.biodiversity.org.au/taxon/apni/5161...
# 2  https://id.biodiversity.org.au/taxon/apni/5177...
# 3  https://id.biodiversity.org.au/taxon/apni/5177...
# 4  https://id.biodiversity.org.au/taxon/apni/5177...
# 5  https://id.biodiversity.org.au/taxon/apni/5177...
# 6  https://id.biodiversity.org.au/taxon/apni/5177...
# 7  https://id.biodiversity.org.au/taxon/apni/5177...
# 8  https://id.biodiversity.org.au/taxon/apni/5177...
# 9  https://id.biodiversity.org.au/taxon/apni/5177...
#
#                                   scientific_name_id
# 0  https://id.biodiversity.org.au/name/apni/51342600
# 1    https://id.biodiversity.org.au/name/apni/190758
# 2     https://id.biodiversity.org.au/name/apni/55929
# 3     https://id.biodiversity.org.au/name/apni/55937
# 4    https://id.biodiversity.org.au/name/apni/116920
# 5     https://id.biodiversity.org.au/name/apni/55945
# 6     https://id.biodiversity.org.au/name/apni/55953
# 7    https://id.biodiversity.org.au/name/apni/116595
# 8    https://id.biodiversity.org.au/name/apni/243806
# 9     https://id.biodiversity.org.au/name/apni/55961

# %% [markdown]
# * Counts of each taxon rank:

# %%
taxa_df.taxon_rank.value_counts()
# Out:
# taxon_rank
# species       26807
# subspecies     2970
# genus          2022
# variety        1326
# form             86
# family           68
# series           20
# Name: count, dtype: int64

# %%
total_feature_samples = sample_counts2_df.Counts.sum()
print(f'Total sample count across all 46 selected features: {total_feature_samples}')
# Out:
# Total sample count across all 46 selected features: 379188

# %%
total_top10_feature_samples = sample_counts2_df.iloc[0:10].Counts.sum()
total_top10_feature_samples_pcnt = int(total_top10_feature_samples/total_feature_samples * 100)
print('Total sample count across largest 10 selected features: {}.\nSo, {}% belong to the 10 largest features.'.format(total_top10_feature_samples, total_top10_feature_samples_pcnt))
# Out:
# Total sample count across largest 10 selected features: 284164.
# So, 74% belong to the 10 largest features.

# %%
print(f'The ratio of total samples to total species (ignoring the other taxon ranks) is: {total_feature_samples/taxa_df.taxon_rank.value_counts().iloc[0]}')
print(f'The ratio of top 10 feature samples to total species (ignoring the other taxon ranks) is: {total_top10_feature_samples/taxa_df.taxon_rank.value_counts().iloc[0]}')
# Out:
# The ratio of total samples to total species (ignoring the other taxon ranks) is: 14.145111351512664
# The ratio of top 10 feature samples to total species (ignoring the other taxon ranks) is: 10.600365576155482

# %% [markdown]
# ### Notes
# * The largest count for a feature is 52,096 for maximum `plant_height`, with 379,188 across all 46 features, three quarters belonging to just the top 10 features by size. Meanwhile there are 26,807 species listed in taxa.csv. Compared to the top 10 features there is an average of 10.6 samples per sepcies. However, it is likely not all taxa are equally represented by the data and some taxa may not be present in traits.csv.

# %% [markdown]
# ## 3.5. Analyze Taxon Rank between taxa.csv and traits.csv

# %% [markdown]
# * taxa.csv lists seven taxon ranks, which is counted in the previous section. The order of the ranks:
#   * family (68)
#   * genus (2022)
#     * series (20) **
#   * species (26807)
#   * subspecies (2970)
#   * variety (1326) **
#   * form (86) **
#
# * ** However, 'variety' and 'form' can all directly branch of any rank above them, up to 'species', while, according to [wikipedia](https://en.wikipedia.org/wiki/Series_(botany)), a 'series' can be used to divide up a genus with a very large number of species; referencing Christensen (1987; Nordic J. Botany 7: 383-408; see p.384):
#
# >"_The species concept used in the present work is morphological, and mostly in line with Rothmaler (1944) and Du Rietz (1930). The taxonomic ranks used are defined as follows:_
# >
# >_**Forma** of a variety, subspecies or species occurs sporadically within the distribution area of the taxon of higher rank to which it is referred and differs from that taxon in a single character._
# >
# >_**Varietas** of a subspecies or species is to some extent allopatric and forms local, distinct populations as well as mixed, integrating populations within the distribution area of the subspecies or species. They differ from each other in usually more than a single, distinct character._
# >
# >_**Subspecies** of a species are both regionally and locally allopatric. They differ from each other in several, distinct characters, but intergrade in overlapping areas._
# >
# >_**Species** of a genus differ from each other in numerous, distinct characters and have a characteristic distribution area of their own. Where closely related species meet occasional hybridization and introgression may occur._"
#
#
# * Within taxa.csv, the `taxon_rank` field affects the content on the `taxon_name` field:
#   * If the rank is 'family', `taxon_name` equals  or starts with the `family` field. The `genus` field is blank.
#   * If the rank is 'genus', `taxon_name`  equals or starts with the `genus` field. The `family` field is populated.
#   * If the rank is 'species', `taxon_name` equals the `binomial` field. The `trinomial` field is blank.
#   * If the rank is 'subspecies', `taxon_name` equals the `trinomial` field. The `trinomial` field starts with the `binomial` field, folowed by ' subsp. ', followed by the subspecies suffix.
#   * If the rank is 'variety', `taxon_name` equals the `trinomial` field. The `trinomial` field starts with the `binomial` field, folowed by ' var. ', followed by the variety suffix. The binomial is the same as the species so there is no indication if the variety is that of a subspecies, only the species.
#   * If the rank is 'form', `taxon_name` equals the `trinomial` field. The `trinomial` field starts with the `binomial` field, folowed by ' f. ', followed by the form suffix. The binomial is the same as the species so there is no indication if the form is that of a subspecies or variety, only the species.
#   * If the rank is 'series', `taxon_name` equals the `trinomial` field. The `trinomial` field starts with the `binomial` field, folowed by ' ser. ', followed by the series suffix.
#     * 19 of the 'series' are genus Dryandra, which includes two subspecies. The only other series is Eucalyptus ser. Diversiformae. All of these currently have the `taxonomic_status` of 'unplaced', indicating they don't fit in their hierarchy, which can be due to various reasons, including source material problems.
#   * 68 `taxon_name`'s are missing data for the other fields.
#
#
# * Entries in traits.csv for a family would likely apply to its subordinate ranks, but such traits likely do not pertain to the selected traits being observed. For example, 'Malvaceae sp. [White_2020]':

# %%
traits_df[traits_df.taxon_name.str.startswith('Malvaceae sp. [White_2020]')]
# Out:
#          dataset_id                  taxon_name  observation_id  \
# 1659829  White_2020  Malvaceae sp. [White_2020]            4865
# 1659830  White_2020  Malvaceae sp. [White_2020]            4865
# 1659831  White_2020  Malvaceae sp. [White_2020]            4865
# 1659832  White_2020  Malvaceae sp. [White_2020]            4865
# 1659833  White_2020  Malvaceae sp. [White_2020]            4865
# 1659834  White_2020  Malvaceae sp. [White_2020]            4865
# 1659835  White_2020  Malvaceae sp. [White_2020]            4865
# 1659836  White_2020  Malvaceae sp. [White_2020]            4865
# 1659837  White_2020  Malvaceae sp. [White_2020]            4865
# 1659838  White_2020  Malvaceae sp. [White_2020]            4865
# 1659839  White_2020  Malvaceae sp. [White_2020]            4865
# 1659840  White_2020  Malvaceae sp. [White_2020]            4865
# 1659841  White_2020  Malvaceae sp. [White_2020]            4865
# 1659842  White_2020  Malvaceae sp. [White_2020]            4865
# 1659843  White_2020  Malvaceae sp. [White_2020]            4865
# 1659844  White_2020  Malvaceae sp. [White_2020]            4865
# 1659845  White_2020  Malvaceae sp. [White_2020]            4865
#
#                                 trait_name  \
# 1659829                 dispersal_syndrome
# 1659830                         dispersers
# 1659831                           lifespan
# 1659832                    nitrogen_fixing
# 1659833                          parasitic
# 1659834             photosynthetic_pathway
# 1659835                  plant_growth_form
# 1659836  plant_physical_defence_structures
# 1659837         plant_tolerance_inundation
# 1659838               plant_tolerance_salt
# 1659839               plant_tolerance_snow
# 1659840               pollination_syndrome
# 1659841              reproductive_maturity
# 1659842               resprouting_capacity
# 1659843                 seedbank_longevity
# 1659844           seedbank_longevity_class
# 1659845    vegetative_reproduction_ability
#
#                                                      value unit entity_type  \
# 1659829                                           zoochory  NaN     species
# 1659830                                      invertebrates  NaN     species
# 1659831                                              1--10    a     species
# 1659832                                 non_nitrogen_fixer  NaN     species
# 1659833                                      not_parasitic  NaN     species
# 1659834                                                 c3  NaN     species
# 1659835                                               herb  NaN     species
# 1659836                                             absent  NaN     species
# 1659837  1-6_months greater_than_6_months less_than_1_m...  NaN     species
# 1659838                       salinity_tolerance_undefined  NaN     species
# 1659839                                     not_applicable  NaN     species
# 1659840                                             insect  NaN     species
# 1659841                                               0--1    a     species
# 1659842                                        fire_killed  NaN     species
# 1659843                                                2--    a     species
# 1659844                                         persistent  NaN     species
# 1659845                                     not_vegetative  NaN     species
#
#         value_type basis_of_value replicates   basis_of_record life_stage  \
# 1659829       mode   expert_score        NaN  literature field      adult
# 1659830       mode   expert_score        NaN  literature field      adult
# 1659831        bin   expert_score        NaN  literature field      adult
# 1659832       mode   expert_score        NaN  literature field      adult
# 1659833       mode   expert_score        NaN  literature field      adult
# 1659834       mode   expert_score        NaN  literature field      adult
# 1659835       mode   expert_score        NaN  literature field      adult
# 1659836       mode   expert_score        NaN  literature field      adult
# 1659837       mode   expert_score        NaN  literature field      adult
# 1659838       mode   expert_score        NaN  literature field      adult
# 1659839       mode   expert_score        NaN  literature field      adult
# 1659840       mode   expert_score        NaN  literature field      adult
# 1659841        bin   expert_score        NaN  literature field      adult
# 1659842       mode   expert_score        NaN  literature field      adult
# 1659843        bin   expert_score        NaN  literature field      adult
# 1659844       mode   expert_score        NaN  literature field      adult
# 1659845       mode   expert_score        NaN  literature field      adult
#
#         population_id  individual_id  repeat_measurements_id  \
# 1659829           NaN            NaN                     NaN
# 1659830           NaN            NaN                     NaN
# 1659831           NaN            NaN                     NaN
# 1659832           NaN            NaN                     NaN
# 1659833           NaN            NaN                     NaN
# 1659834           NaN            NaN                     NaN
# 1659835           NaN            NaN                     NaN
# 1659836           NaN            NaN                     NaN
# 1659837           NaN            NaN                     NaN
# 1659838           NaN            NaN                     NaN
# 1659839           NaN            NaN                     NaN
# 1659840           NaN            NaN                     NaN
# 1659841           NaN            NaN                     NaN
# 1659842           NaN            NaN                     NaN
# 1659843           NaN            NaN                     NaN
# 1659844           NaN            NaN                     NaN
# 1659845           NaN            NaN                     NaN
#
#          temporal_context_id source_id  location_id  entity_context_id  \
# 1659829                  1.0       NaN          NaN                NaN
# 1659830                  1.0       NaN          NaN                NaN
# 1659831                  1.0       NaN          NaN                NaN
# 1659832                  1.0       NaN          NaN                NaN
# 1659833                  1.0       NaN          NaN                NaN
# 1659834                  1.0       NaN          NaN                NaN
# 1659835                  1.0       NaN          NaN                NaN
# 1659836                  1.0       NaN          NaN                NaN
# 1659837                  1.0       NaN          NaN                NaN
# 1659838                  1.0       NaN          NaN                NaN
# 1659839                  1.0       NaN          NaN                NaN
# 1659840                  1.0       NaN          NaN                NaN
# 1659841                  1.0       NaN          NaN                NaN
# 1659842                  1.0       NaN          NaN                NaN
# 1659843                  1.0       NaN          NaN                NaN
# 1659844                  1.0       NaN          NaN                NaN
# 1659845                  1.0       NaN          NaN                NaN
#
#          plot_context_id  treatment_context_id collection_date  \
# 1659829              NaN                   NaN    unknown/2020
# 1659830              NaN                   NaN    unknown/2020
# 1659831              NaN                   NaN    unknown/2020
# 1659832              NaN                   NaN    unknown/2020
# 1659833              NaN                   NaN    unknown/2020
# 1659834              NaN                   NaN    unknown/2020
# 1659835              NaN                   NaN    unknown/2020
# 1659836              NaN                   NaN    unknown/2020
# 1659837              NaN                   NaN    unknown/2020
# 1659838              NaN                   NaN    unknown/2020
# 1659839              NaN                   NaN    unknown/2020
# 1659840              NaN                   NaN    unknown/2020
# 1659841              NaN                   NaN    unknown/2020
# 1659842              NaN                   NaN    unknown/2020
# 1659843              NaN                   NaN    unknown/2020
# 1659844              NaN                   NaN    unknown/2020
# 1659845              NaN                   NaN    unknown/2020
#
#         measurement_remarks  method_id  method_context_id   original_name
# 1659829                 NaN        1.0                NaN  Malvaceae spp.
# 1659830                 NaN        1.0                NaN  Malvaceae spp.
# 1659831                 NaN        1.0                NaN  Malvaceae spp.
# 1659832                 NaN        1.0                NaN  Malvaceae spp.
# 1659833                 NaN        1.0                NaN  Malvaceae spp.
# 1659834                 NaN        1.0                NaN  Malvaceae spp.
# 1659835                 NaN        1.0                NaN  Malvaceae spp.
# 1659836                 NaN        1.0                NaN  Malvaceae spp.
# 1659837                 NaN        1.0                NaN  Malvaceae spp.
# 1659838                 NaN        1.0                NaN  Malvaceae spp.
# 1659839                 NaN        1.0                NaN  Malvaceae spp.
# 1659840                 NaN        1.0                NaN  Malvaceae spp.
# 1659841                 NaN        1.0                NaN  Malvaceae spp.
# 1659842                 NaN        1.0                NaN  Malvaceae spp.
# 1659843                 NaN        1.0                NaN  Malvaceae spp.
# 1659844                 NaN        1.0                NaN  Malvaceae spp.
# 1659845                 NaN        1.0                NaN  Malvaceae spp.

# %% [markdown]
# * `taxon_rank` of 'family' and 'genus' will be dropped from traits for observations.
# * The selected features could vary by series, species, subspecies, variety or form so each taxon_name could be treated independent of eachother, such that each would be a class. However, this depends on there being sufficient data.
#   * If there is insufficient sample counts, then existing samples could be rolled up into genus, which would then be the only classes.
#   * This might have unexpected consequences. Some species may generalize better while other species' details may be lost in the model due to underfitting.
# ### Filtering and merging:

# %%
# Only rows with desired traits
traits_filtered_df = traits_df[traits_df.trait_name.apply(lambda trait: trait in selected_traits2)]
# Only for adult plants
traits_filtered_df = traits_filtered_df[traits_filtered_df.life_stage == 'adult']

# %%
# Only columns of use to modelling
traits_filtered_df = traits_filtered_df[['taxon_name', 'observation_id', 'trait_name', 'value', 'unit', 'value_type', 'basis_of_value']]

# %%
# Remove genus and family entries
taxa_filtered_df = taxa_df[taxa_df.taxon_rank.apply(lambda rank: rank not in ['genus', 'family'])]
taxa_filtered_df = taxa_filtered_df[['taxon_name', 'taxon_rank', 'genus', 'family']]

# %%
# Inner merge on taxon_name
trait_filt_df = pd.merge(traits_filtered_df, taxa_filtered_df, left_on='taxon_name', right_on='taxon_name', how="inner")

# %%
trait_filt_df[trait_filt_df.basis_of_value != 'measurement'].head(10)
# Out:
#                   taxon_name  observation_id     trait_name value     unit  \
# 272954  Acacia fasciculifera              11   plant_height    20        m
# 272957  Acacia fasciculifera              12  leaflet_count     1  {count}
# 272962    Acacia melanoxylon              24   plant_height    30        m
# 272965    Acacia melanoxylon              25  leaflet_count     1  {count}
# 272969   Acalypha capillipes              35   plant_height     4        m
# 272972   Acalypha capillipes              36  leaflet_count     1  {count}
# 272981     Ackama paniculosa              51   plant_height    40        m
# 272984     Ackama paniculosa              52  leaflet_count     5  {count}
# 272987  Syzygium hemilamprum              60   plant_height    35        m
# 272990  Syzygium hemilamprum              61  leaflet_count     1  {count}
#
#        value_type basis_of_value taxon_rank     genus         family
# 272954    maximum   expert_score    species    Acacia       Fabaceae
# 272957       mode   expert_score    species    Acacia       Fabaceae
# 272962    maximum   expert_score    species    Acacia       Fabaceae
# 272965       mode   expert_score    species    Acacia       Fabaceae
# 272969    maximum   expert_score    species  Acalypha  Euphorbiaceae
# 272972       mode   expert_score    species  Acalypha  Euphorbiaceae
# 272981    maximum   expert_score    species    Ackama    Cunoniaceae
# 272984       mode   expert_score    species    Ackama    Cunoniaceae
# 272987    maximum   expert_score    species  Syzygium      Myrtaceae
# 272990       mode   expert_score    species  Syzygium      Myrtaceae

# %% [markdown]
# ### Samples per taxon_name

# %%
# Calculate average samples per taxon_name/trait_name/value_type
temp = trait_filt_df[['taxon_name', 'trait_name', 'value_type', 'observation_id']].groupby(['taxon_name', 'trait_name', 'value_type']).count().rename(columns={'observation_id': 'counts'})
print(f'Average samples per taxon_name/trait_name/value_type: {temp.counts.mean()}')
# Out:
# Average samples per taxon_name/trait_name/value_type: 1.7753787915743875

# %% [markdown]
# * There are only about 1.8 samples per `trait_name`/`value_type` for each class (a.k.a. `taxon_name`)
# * This isn't sufficient for model training, as there would be insuficient

# %% [markdown]
# ### Samples per genus

# %%
# Calculate average samples per taxon_name/trait_name/value_type
temp = trait_filt_df[['genus', 'trait_name', 'value_type', 'observation_id']].groupby(['genus', 'trait_name', 'value_type']).count().rename(columns={'observation_id': 'counts'})
print(f'Average samples per genus/trait_name/value_type: {temp.counts.mean()}')
# Out:
# Average samples per genus/trait_name/value_type: 8.120710825352175

# %% [markdown]
# * The result of 8 samples on average per genus is better but unlikely sufficient as there will be variation per genus
# * Viewing the largest and smallest count:

# %%
print(f'Largest genus count of trait_name/value_type: {temp.loc[temp['counts'].idxmax()]}\n')
print(f'Smallest genus count of trait_name/value_type: {temp.loc[temp['counts'].idxmin()]}')
# Out:
# Largest genus count of trait_name/value_type: counts    3851
# Name: (Acacia, plant_height, maximum), dtype: int64
#
# Smallest genus count of trait_name/value_type: counts    1
# Name: (Abelia, leaf_length, maximum), dtype: int64

# %% [markdown]
# * All the counts for "plant_height, maximum":

# %%
temp.loc[(slice(None), 'plant_height', 'maximum')]
# Out:
#                       counts
# genus
# Abelia                     1
# Abelmoschus               11
# Abildgaardia               4
# Abroma                     2
# Abrophyllum                4
# Abrotanella                5
# Abrus                      1
# Abutilon                  84
# Acacia                  3851
# Acaciella                  3
# Acaena                    32
# Acalypha                  26
# Acanthocarpus             11
# Acanthospermum             4
# Acanthus                   8
# Acer                      11
# Aceratium                 11
# Achillea                  10
# Achyranthes               10
# Acianthus                 15
# Acidonia                   3
# Aciphylla                  6
# Ackama                     6
# Acmella                    7
# Acmena                     1
# Acokanthera                1
# Acomis                     1
# Acrachne                   2
# Acradenia                  8
# Acroceras                  1
# Acronychia                83
# Acrophyllum                1
# Acrostichum                3
# Acrothamnus               14
# Acrotriche                37
# Actephila                 25
# Actinobole                13
# Actinodium                 3
# Actinoschoenus             1
# Actinoscirpus              1
# Actinostachys              1
# Actinotus                 25
# Actites                    6
# Acunniana                  1
# Adansonia                  3
# Adelphacme                 3
# Adenanthera                6
# Adenanthos                84
# Adenia                     2
# Adenocarpus                1
# Adenostemma                9
# Adiantum                   8
# Adonis                     4
# Adriana                   17
# Aegialitis                 4
# Aegiceras                  7
# Aegle                      1
# Aegopodium                 2
# Aenictophyton              2
# Aeonium                    6
# Aerva                      6
# Aeschynomene               9
# Afrocarpus                 1
# Afrohybanthus             13
# Agapanthus                 4
# Agastachys                 4
# Agathis                    6
# Agave                      4
# Ageratina                  7
# Ageratum                   8
# Aggreflorum                3
# Agiortia                   3
# Aglaia                    39
# Agonis                     8
# Agrimonia                  1
# Agrostemma                 2
# Agrostis                  27
# Agrostocrinum              6
# Aidia                      7
# Ailanthus                 12
# Aira                      23
# Aizoon                     3
# Ajuga                      6
# Akania                     6
# Alangium                  14
# Alania                     1
# Albizia                   18
# Albuca                     3
# Alcea                      2
# Alchemilla                 2
# Alchornea                 11
# Alectryon                 54
# Aleurites                  8
# Alexfloydia                1
# Alexgeorgea                6
# Alhagi                     4
# Alisma                     8
# Alkekengi                  1
# Allamanda                  3
# Alliaria                   1
# Allittia                   7
# Allium                    19
# Allocasuarina            191
# Allophylus                 2
# Allopterigeron             1
# Allosyncarpia              2
# Alloteropsis               4
# Alloxylon                  9
# Almaleea                  10
# Alnus                      2
# Alocasia                   4
# Aloe                       6
# Alopecurus                 9
# Alphitonia                26
# Alpinia                   15
# Alstonia                  30
# Alstroemeria               1
# Alternanthera             15
# Althenia                   8
# Aluta                     18
# Alyogyne                  19
# Alysicarpus               10
# Alyssum                    6
# Alyxia                    38
# Amaracarpus                2
# Amaranthus                71
# Amaryllis                  1
# Ambrosia                  14
# Amelichloa                 5
# Ammannia                  22
# Ammi                       5
# Ammobium                   4
# Ammothryon                 1
# Amomum                     4
# Amorphophallus             5
# Amorphospermum             4
# Ampelocissus               1
# Ampelopteris               1
# Amperea                   29
# Amphibolis                 6
# Amphibromus               26
# Amphipogon                45
# Amsinckia                 11
# Amyema                     7
# Anacampseros               2
# Anacolosa                  2
# Anacyclus                  1
# Ananas                     1
# Anarthria                 15
# Anchusa                    6
# Ancistrachne               3
# Andersonia                63
# Androcalva                24
# Andropogon                 5
# Androstoma                 1
# Aneilema                   4
# Anemocarpa                 5
# Anemone                    2
# Anethum                    1
# Angianthus                32
# Angiopteris                3
# Angophora                 46
# Anigozanthos              35
# Anisomeles                 2
# Anisopogon                 5
# Annona                    10
# Anoda                      3
# Anodopetalum               4
# Anogramma                  2
# Anopterus                  8
# Anredera                   1
# Anthelepis                 1
# Anthemis                   9
# Anthobolus                10
# Anthocarapa                4
# Anthocercis               31
# Anthosachne               14
# Anthotium                 12
# Anthotroche                5
# Anthoxanthum               4
# Anthriscus                 1
# Anthyllis                  1
# Antiaris                   6
# Anticoryne                 6
# Antidesma                 15
# Antirhea                  10
# Aotus                     38
# Apalochlamys               3
# Apatophyllum               4
# Apera                      1
# Aphananthe                 5
# Aphanes                    7
# Aphanopetalum              4
# Aphelia                   14
# Aphyllodium                7
# Apium                     19
# Apluda                     1
# Apodasmia                  2
# Apodytes                   3
# Aponogeton                 1
# Apowollastonia            13
# Aquilegia                  3
# Arabidella                19
# Arabidopsis                3
# Araucaria                 12
# Araujia                    3
# Arbutus                    3
# Archeria                  11
# Archidendron              31
# Archidendropsis            7
# Archirhodomyrtus           4
# Archontophoenix            9
# Arctium                    6
# Arctotheca                21
# Arctotis                   5
# Ardisia                   21
# Arenaria                   4
# Arenga                     4
# Areocleome                 2
# Argemone                  12
# Argentina                  1
# Argentipallium            10
# Argophyllum               14
# Argusia                    6
# Argyranthemum              5
# Argyrodendron             31
# Argyroglottis              1
# Argyrotegium              10
# Arisarum                   2
# Aristea                    1
# Aristida                 176
# Aristolochia               2
# Aristotelia                4
# Arivela                   28
# Arnocrinum                 4
# Arrhenatherum              5
# Arrhenechthites            2
# Artanema                   2
# Artemisia                  9
# Arthragrostis              8
# Arthraxon                  3
# Arthropodium              44
# Arthropteris               1
# Arthrostylis               3
# Artocarpus                 3
# Arum                       2
# Aruncus                    1
# Arundina                   1
# Arundinella                7
# Arundo                     3
# Arytera                   28
# Asclepias                  7
# Asparagus                 21
# Asperula                  19
# Asphodelus                 4
# Asplenium                 19
# Astartea                  75
# Astelia                    3
# Asteridea                 13
# Asteriscus                 2
# Asterolasia               51
# Asteromyrtus               8
# Asterotrichion             2
# Astonia                    1
# Astrebla                  16
# Astroloma                  3
# Astrotricha               47
# Astus                      9
# Asystasia                  3
# Atalaya                   39
# Atherosperma               9
# Athertonia                 2
# Athrotaxis                10
# Atkinsonia                 2
# Atractocarpus             25
# Atriplex                 265
# Auranticarpa              19
# Australina                 5
# Australopyrum              4
# Austrobaeckea              9
# Austrobaileya              1
# Austrobryonia              1
# Austrobuxus                5
# Austrochloris              1
# Austrocylindropuntia       6
# Austrodolichos             1
# Austrolycopodium           1
# Austromatthaea             3
# Austromuellera             7
# Austromyrtus               4
# Austrosteenisia            1
# Austrostipa              284
# Avellinia                  3
# Avena                     25
# Avicennia                 21
# Axonopus                   5
# Azadirachta                2
# Azanza                     4
# Azolla                     4
# Azorella                   3
# Babiana                    8
# Babingtonia               16
# Baccharis                  2
# Backhousia                29
# Bacopa                     1
# Baeckea                  101
# Baeometra                  3
# Baileyoxylon               3
# Balanophora                1
# Balanops                   2
# Balaustion                18
# Balladonia                 1
# Ballantinia                2
# Ballota                    3
# Baloghia                  11
# Baloskion                  7
# Bambusa                    4
# Banksia                  539
# Barbarea                  10
# Barklya                    4
# Barleria                   3
# Barongia                   2
# Barringtonia              18
# Basella                    1
# Basilicum                  2
# Bassia                     2
# Batis                      4
# Bauera                    11
# Bauhinia                   2
# Baumea                     8
# Baxteria                   2
# Beaufortia                29
# Bedfordia                 17
# Beilschmiedia             31
# Bellardia                 10
# Bellendena                 3
# Bellida                    2
# Benstonea                  6
# Bentleya                   2
# Berberis                  12
# Bergenia                   1
# Bergia                    13
# Berkheya                   4
# Berrya                     3
# Bertya                    65
# Berula                     4
# Beta                       3
# Betula                     2
# Beyeria                   48
# Biancaea                   1
# Bidens                    24
# Bifora                     2
# Billardiera               16
# Biophytum                  1
# Bischofia                  2
# Biserrula                  1
# Bixa                       1
# Blackallia                 2
# Blackstonia                2
# Blainvillea                6
# Blancoa                    2
# Blandfordia                3
# Bleasdalea                 2
# Blechnum                  14
# Blennodia                  6
# Blennospora               17
# Blepharocarya              4
# Blumea                    28
# Bobea                      2
# Boea                       2
# Boehmeria                  5
# Boerhavia                 11
# Bolboschoenus              5
# Bombax                     7
# Bonamia                    7
# Bonnaya                    3
# Borago                     4
# Boronia                  422
# Borya                     29
# Bosistoa                  21
# Bossiaea                 114
# Bothriochloa              30
# Botrychium                 2
# Bouchardatia               5
# Bowenia                    4
# Brachychiton              69
# Brachyloma                28
# Brachypodium               6
# Brachyscias                2
# Brachyscome              153
# Brachysola                 2
# Brachystelma               1
# Brackenridgea              4
# Brassiantha                2
# Brassica                  31
# Breynia                   20
# Bridelia                  20
# Brillantaisia              1
# Briza                     14
# Brombya                    7
# Bromus                    52
# Broussonetia               1
# Brownlowia                 2
# Brucea                     4
# Brugmansia                 2
# Bruguiera                 20
# Brunonia                  11
# Brunoniella                5
# Bryophyllum                5
# Bubbia                    16
# Buchanania                13
# Buchnera                   6
# Buckinghamia               4
# Buddleja                  10
# Buglossoides               4
# Bulbine                   31
# Bulbophyllum               1
# Bulbostylis                5
# Bupleurum                  5
# Burchardia                23
# Burmannia                  5
# Burnettia                  1
# Bursaria                  41
# Butomopsis                 1
# Byblis                     6
# Cadaba                     3
# Cadellia                   2
# Caesalpinia                8
# Caesia                    35
# Cajanus                   17
# Cakile                     5
# Caladenia                355
# Calamagrostis              3
# Calamintha                 1
# Calamphoreus               2
# Calamus                   13
# Calandrinia               73
# Calanthe                   1
# Calceolaria                1
# Caldesia                   2
# Caleana                   22
# Calectasia                21
# Calendula                 10
# Calibrachoa                1
# Calicotome                 1
# Calliandra                 1
# Callicarpa                14
# Callicoma                  4
# Callistachys               4
# Callistemon               72
# Callitriche                3
# Callitris                 68
# Calocephalus              15
# Calochilus                23
# Calochlaena                2
# Calomeria                  2
# Calophyllum               23
# Calorophus                 1
# Calothamnus               63
# Calotis                   70
# Calotropis                 7
# Calycopeplus               5
# Calyptochloa               2
# Calystegia                 4
# Calytrix                 193
# Camelina                   6
# Camellia                   2
# Camonea                    1
# Campanula                  1
# Campsis                    1
# Camptacra                  1
# Camptostemon               3
# Campynema                  2
# Cananga                    3
# Canarium                  18
# Canavalia                  2
# Canna                      7
# Cannabis                   3
# Canscora                   2
# Cansjera                   2
# Capillipedium              6
# Capnophyllum               1
# Capparis                  57
# Capsella                   6
# Capsicum                   6
# Carallia                   5
# Cardamine                 40
# Cardiospermum              3
# Carduus                   18
# Cardwellia                 5
# Carex                     70
# Carinavalva                1
# Carissa                   17
# Carmichaelia               2
# Carnarvonia                5
# Carpentaria                2
# Carpesium                  2
# Carpha                     4
# Carpobrotus               14
# Carrichtera                5
# Carronia                   1
# Carthamus                 17
# Cartonema                 10
# Caryota                    2
# Cascabela                  6
# Casearia                  19
# Cassia                    19
# Cassinia                  89
# Cassytha                  11
# Castanospermum             5
# Castanospora               7
# Castilla                   1
# Castilleja                 3
# Casuarina                 44
# Catacolea                  1
# Catalepidia                2
# Catapodium                 4
# Catharanthus               6
# Cathormion                 6
# Causonis                   1
# Caustis                   11
# Cayratia                   1
# Cecropia                   2
# Cedronella                 1
# Cedrus                     1
# Ceiba                      1
# Celastrus                  2
# Celmisia                   5
# Celosia                    3
# Celtis                    24
# Cenarrhenes                3
# Cenchrus                  58
# Centaurea                 41
# Centaurium                15
# Centella                   7
# Centipeda                 41
# Centotheca                 3
# Centranthera               2
# Centranthus                6
# Centratherum               4
# Centrolepis               93
# Centromadia                1
# Centropappus               2
# Centrosema                 1
# Ceodes                     5
# Cephalaralia               2
# Cephalipterum              5
# Cephalosorus               1
# Cephalotus                 2
# Cerastium                  8
# Ceratogyne                10
# Ceratonia                  2
# Ceratopetalum             15
# Ceratopteris               1
# Cerbera                   11
# Cereus                     1
# Ceriops                    7
# Cestrum                   14
# Chaenomeles                1
# Chaenostoma                1
# Chaetanthus                7
# Chaetospora                8
# Chamaecrista              29
# Chamaecyparis              1
# Chamaecytisus              3
# Chamaemelum                3
# Chamaeraphis               1
# Chamaescilla              14
# Chamaexeros                6
# Chamelaucium              40
# Chascolytrum               1
# Chasmanthe                 8
# Cheilanthes               32
# Cheilocostus               2
# Cheiranthera              17
# Cheirostylis               2
# Chenopodium               69
# Cheyniana                  3
# Chiloglottis              17
# Chionachne                 7
# Chionanthus               10
# Chionochloa                5
# Chisocheton                4
# Chloanthes                 5
# Chloris                   37
# Chlorophytum               5
# Chondrilla                 6
# Chondropyxis               2
# Chordifex                 29
# Choretrum                 27
# Choriceras                 6
# Chorilaena                 3
# Chorispora                 1
# Chorizandra                8
# Chorizema                 32
# Christella                 2
# Christia                   1
# Chromolaena                4
# Chrozophora                3
# Chrysanthemoides           9
# Chrysitrix                 1
# Chrysocephalum            35
# Chrysocoma                 2
# Chrysopogon               20
# Chthonocephalus           10
# Chukrasia                  2
# Cicendia                   8
# Cichorium                  5
# Cineraria                  2
# Cinnamomum                18
# Cirsium                   12
# Cissus                     2
# Cistus                     7
# Citronella                 8
# Citrullus                  2
# Citrus                    23
# Cladium                    3
# Claoxylon                 17
# Clausena                   4
# Clausospicula              1
# Claytonia                  1
# Cleidion                   2
# Cleistanthus              19
# Cleistochloa               3
# Clematicissus              2
# Clematis                  29
# Cleome                     3
# Cleretum                   6
# Clerodendrum              41
# Clinopodium                1
# Clitoria                   3
# Cnesmocarpon               3
# Coatesia                   5
# Coccinia                   1
# Cochlospermum             11
# Cocos                      2
# Codiaeum                   5
# Codonocarpus              12
# Coelachne                  1
# Coelospermum               6
# Coffea                     5
# Coix                       3
# Coleocoma                  2
# Coleonema                  3
# Coleus                    37
# Collomia                   2
# Colobanthus                7
# Colocasia                  6
# Colubrina                  4
# Combretum                  1
# Comesperma                67
# Commelina                  7
# Commersonia               32
# Commicarpus                3
# Conicosia                  2
# Conium                     4
# Connarus                   1
# Conospermum              170
# Conostephium              13
# Conostylis               157
# Conothamnus                5
# Conringia                  3
# Consolida                  2
# Convolvulus               12
# Coopernookia              15
# Coprosma                  39
# Corchorus                 36
# Cordia                    14
# Cordyline                 28
# Coreopsis                  4
# Coriandrum                 2
# Cornus                     2
# Corokia                    7
# Coronidium                33
# Correa                    98
# Corrigiola                 1
# Corsia                     1
# Cortaderia                 4
# Corunastylis              45
# Corybas                   18
# Corymbia                 411
# Corymborkis                1
# Corynanthera               1
# Corynephorus               1
# Corynocarpus              13
# Corynotheca               13
# Corypha                    2
# Cosmelia                   2
# Cosmos                     5
# Cossinia                   2
# Costus                     1
# Cota                       1
# Cotoneaster               14
# Cotula                    38
# Cotyledon                  6
# Crambe                     1
# Craspedia                 41
# Crassocephalum             4
# Crassula                  87
# Crataegus                  2
# Crateva                    5
# Cratystylis               13
# Crenidium                  2
# Crepis                    21
# Cressa                     4
# Crinum                    10
# Crispiloba                 2
# Cristonia                  2
# Crithmum                   1
# Crocosmia                  3
# Crotalaria                94
# Croton                    64
# Crowea                    15
# Crudia                     4
# Crupina                    1
# Cryptandra                82
# Cryptocarya              152
# Cryptostegia               3
# Cryptostylis               7
# Cucumis                    1
# Cullen                    35
# Cupaniopsis               49
# Cuphea                     3
# Cuphonotus                 8
# Cupressus                  1
# Curculigo                  5
# Curcuma                    2
# Cuscuta                    3
# Cuttsia                    3
# Cyanella                   2
# Cyanicula                 18
# Cyanostegia                5
# Cyanothamnus               4
# Cyanotis                   1
# Cyanthillium              12
# Cyathea                   18
# Cyathochaeta              14
# Cyathodes                  6
# Cyathostemon              13
# Cyathula                   3
# Cycas                     39
# Cyclocarpa                 1
# Cycloloma                  2
# Cyclophyllum              20
# Cyclosorus                 1
# Cyclospermum               5
# Cycnogeton                 7
# Cylindropuntia            19
# Cymbalaria                 2
# Cymbidium                  2
# Cymbonotus                 8
# Cymbopogon                25
# Cynanchum                 14
# Cynara                     7
# Cynodon                   28
# Cynoglossum                5
# Cynometra                  8
# Cynosurus                  7
# Cyperochloa                2
# Cyperus                  137
# Cyphanthera               27
# Cypselocarpus              1
# Cyrtandra                  2
# Cyrtococcum                4
# Cyrtomium                  1
# Cyrtostylis               11
# Cystopteris                1
# Cytisus                    5
# Cytogonidium               2
# Dactylis                   2
# Dactyloctenium            12
# Dahlia                     2
# Dalbergia                  1
# Dallwatsonia               1
# Damasonium                 3
# Dampiera                 174
# Dansiea                    4
# Danthonia                  2
# Daphnandra                17
# Daphne                     1
# Darlingia                  8
# Darwinia                  91
# Dasymalla                  5
# Dasypogon                 10
# Datura                    19
# Daucus                    27
# Davidsonia                 9
# Daviesia                 359
# Debregeasia                1
# Decaschistia               5
# Decaspermum                8
# Decazesia                  1
# Deeringia                  4
# Delairea                   2
# Delarbrea                  6
# Delonix                    4
# Delosperma                 1
# Dendrobium                 6
# Dendrocnide               25
# Dendrolobium               8
# Denhamia                  58
# Dennstaedtia               1
# Dentella                   1
# Deplanchea                 2
# Derris                     1
# Deschampsia                5
# Descurainia                4
# Desmanthus                 2
# Desmocladus               35
# Desmodiopsis               3
# Desmodium                 12
# Desmos                     1
# Deutzia                    1
# Deyeuxia                  91
# Dianella                  82
# Dicarpidium                5
# Dichanthium               27
# Dichapetalum               2
# Dichelachne               30
# Dichondra                  8
# Dichopogon                13
# Dichorisandra              1
# Dichosciadium              1
# Dichrocephala              2
# Dichromochlamys            2
# Dichrostachys              3
# Dicksonia                  5
# Dicladanthera              2
# Dicliptera                 7
# Dicranopteris              2
# Dicrastylis               42
# Dictyoneura                3
# Didymanthus                2
# Didymoplexis               1
# Dielsia                    2
# Dielsiodoxa                5
# Dierama                    5
# Dietes                     4
# Digitalis                  2
# Digitaria                 95
# Dillenia                   4
# Dillwynia                 70
# Dimeria                    7
# Dimocarpus                 5
# Dimorphocoma               1
# Dimorphotheca             14
# Dinebra                   18
# Dinghoua                   3
# Dinosperma                15
# Diocirea                   8
# Diodontium                 2
# Dioscorea                  3
# Diospyros                 60
# Diphasium                  1
# Diplachne                 18
# Diplarrena                 3
# Diplaspis                  5
# Diplazium                  2
# Diplocyclos                1
# Diploglottis              34
# Diplolaena                36
# Diplopeltis                8
# Diplotaxis                 9
# Dipodium                  14
# Dipsacus                   4
# Dipteracanthus             6
# Disa                       3
# Disakisperma               1
# Discaria                   8
# Dischisma                  4
# Diselma                    2
# Disphyma                   6
# Dissiliaria                9
# Dissocarpus               18
# Distichlis                 6
# Distimake                  1
# Dithyrostegia              2
# Dittrichia                 9
# Diuris                    80
# Dockrillia                 2
# Dodonaea                 229
# Dolichandrone              5
# Donatia                    1
# Donella                    2
# Dopatrium                  1
# Doryanthes                 4
# Doryopteris                1
# Doryphora                  9
# Dovyalis                   1
# Draba                      1
# Drabastrum                 1
# Dracaena                   4
# Dracocephalum              1
# Dracophyllum              35
# Drakaea                   16
# Drosanthemum               1
# Drosera                  207
# Drummondita               17
# Dryadodaphne               2
# Drymophila                 7
# Drynaria                   1
# Dryopoa                    4
# Drypetes                  12
# Duboisia                  16
# Dubouzetia                 1
# Duma                      15
# Duperreya                  2
# Duranta                    3
# Durringtonia               1
# Dysoxylum                 59
# Dysphania                 61
# Ecdeiocolea                2
# Echinochloa               41
# Echinopogon               27
# Echinops                   1
# Echium                    13
# Eclipta                   17
# Ectrosia                  26
# Ehretia                   18
# Ehrharta                  30
# Eidothea                   4
# Einadia                   19
# Elachanthus                7
# Elaeagnus                  1
# Elaeocarpus               77
# Elaeodendron              15
# Elatine                    5
# Elatostema                 5
# Elattostachys             15
# Eleocharis                47
# Elephantopus               5
# Eleusine                   9
# Eleutheranthera            3
# Elionurus                  3
# Elythranthera              6
# Elytrigia                  4
# Elytrophorus               6
# Embelia                    2
# Emilia                     5
# Emmenosperma              10
# Empodisma                  6
# Enchylaena                20
# Endiandra                106
# Endospermum                3
# Enekbatus                 21
# Enneapogon                52
# Enteropogon               17
# Entolasia                 10
# Epacris                   99
# Epiblema                   4
# Epilobium                 52
# Epiphyllum                 1
# Epipremnum                 1
# Epitriche                  1
# Eragrostiella              2
# Eragrostis               204
# Erechtites                 3
# Eremaea                   44
# Eremochloa                 4
# Eremophea                  5
# Eremophila               611
# Eremosyne                  2
# Eriachne                 152
# Erica                     12
# Erichsenia                 1
# Ericksonella               1
# Ericomyrtus                7
# Erigeron                  34
# Eriobotrya                 2
# Eriocaulon                74
# Eriocephalus               2
# Eriochilus                25
# Eriochiton                 6
# Eriochlamys                7
# Eriochloa                 19
# Eriosema                   2
# Eriostemon                 6
# Erodiophyllum              4
# Erodium                   52
# Erophila                   5
# Eruca                      4
# Erymophyllum              11
# Eryngium                  30
# Erysimum                   3
# Erythrina                 22
# Erythrophleum              5
# Erythrostemon              3
# Erythroxylum              15
# Escallonia                 1
# Eschenbachia               2
# Eschscholzia               5
# Ethulia                    2
# Ethuliopsis                4
# Etlingera                  2
# Eucalyptus              3182
# Euchilopsis                2
# Euchiton                  28
# Euclidium                  2
# Eucryphia                 16
# Eugenia                    3
# Eulalia                   11
# Eulophia                   2
# Eumachia                   2
# Euodia                     6
# Euonymus                   3
# Eupatorium                 3
# Euphorbia                118
# Euphrasia                 49
# Euploca                   59
# Eupomatia                 16
# Euroschinus                5
# Eurychorda                 2
# Euryomyrtus               25
# Euryops                    6
# Eustachys                  4
# Eustrephus                 4
# Eutaxia                   35
# Evandra                    4
# Everistia                  5
# Evolvulus                  7
# Ewartia                    5
# Exacum                     1
# Excoecaria                12
# Exocarpos                 59
# Facelis                    1
# Fagopyrum                  2
# Fagraea                    9
# Falcataria                 3
# Fallopia                   5
# Faradaya                   2
# Fatoua                     4
# Felicia                    1
# Ferraria                   4
# Festuca                   14
# Ficaria                    1
# Ficinia                    6
# Ficus                    174
# Filago                     3
# Fimbristylis              90
# Firmiana                   2
# Fitzwillia                 1
# Flacourtia                 8
# Flagellaria                4
# Flaveria                   5
# Flemingia                  8
# Flindersia                57
# Florestina                 2
# Floscopa                   1
# Floydia                    5
# Flueggea                   9
# Foeniculum                 4
# Fontainea                 13
# Forstera                   1
# Franciscodendron           3
# Frankenia                 41
# Franklandia                4
# Fraxinus                   7
# Freesia                    5
# Freycinetia                2
# Froelichia                 2
# Fuchsia                    5
# Fuirena                    7
# Fumaria                   18
# Furcraea                   3
# Gahnia                    38
# Gaillardia                 5
# Gaimardia                  2
# Galactia                   3
# Galbulimima                3
# Galinsoga                  4
# Galium                    22
# Gamochaeta                16
# Ganophyllum                4
# Garcinia                  30
# Gardenia                  27
# Garnotia                   2
# Garuga                     4
# Gastridium                 4
# Gastrodia                  6
# Gastrolobium             258
# Gaudium                   11
# Gaultheria                14
# Gazania                    5
# Geijera                   19
# Geitonoplesium             3
# Geleznowia                 5
# Gen.                       1
# Geniostoma                 4
# Genista                   11
# Genoplesium                1
# Gentiana                   4
# Gentianella                2
# Georgeantha                2
# Geranium                  40
# Germainia                  4
# Geum                       2
# Gibasis                    1
# Gilberta                   6
# Gillbeea                   4
# Gilruthia                  1
# Gingidia                   6
# Gladiolus                 33
# Glandularia                5
# Glaucium                   8
# Glebionis                  6
# Gleditsia                  2
# Gleichenia                 6
# Glinus                     3
# Gliricidia                 1
# Glischrocaryon            21
# Globba                     1
# Glochidion                46
# Gloriosa                   1
# Glossocardia               4
# Glossocarya                3
# Glossodia                 10
# Glossostigma               3
# Glyceria                  18
# Glycine                   12
# Glycocystis                2
# Glycosmis                  6
# Glycyrrhiza                6
# Gmelina                   11
# Gnaphalium                12
# Gnephosis                 32
# Gnidia                     2
# Gomphandra                 3
# Gomphocarpus              13
# Gompholobium              74
# Gomphrena                 43
# Gonatopus                  1
# Goniothalamus              2
# Gonocarpus               127
# Goodenia                 492
# Goodia                    14
# Gorteria                   2
# Gossia                    49
# Gossypium                 23
# Grammatotheca              3
# Grammosolen                5
# Granitites                 2
# Graptophyllum              7
# Gratiola                  19
# Gratwickia                 1
# Grevillea               1115
# Grewia                    32
# Grindelia                  3
# Griselinia                 1
# Grona                     23
# Guettarda                  3
# Guichenotia               22
# Guilfoylia                 5
# Guioa                     23
# Guizotia                   2
# Gunnera                    1
# Gunniopsis                31
# Gymnanthera                4
# Gymnema                    9
# Gymnocoronis               2
# Gymnoschoenus              4
# Gymnosporia                3
# Gymnostachys               4
# Gymnostoma                 3
# Gynandropsis               3
# Gynatrix                   7
# Gynochthodes               1
# Gynura                     4
# Gypsophila                 7
# Gyrocarpus                 9
# Gyrostemon                38
# Hackelia                  10
# Hackelochloa               2
# Haeckeria                  2
# Haegiela                   3
# Haematoxylum               1
# Haemodorum                60
# Hainardia                  5
# Hakea                    476
# Halfordia                  7
# Halgania                  35
# Haloragis                 80
# Haloragodendron           15
# Handroanthus               2
# Hanguana                   4
# Hannafordia                8
# Hanslia                    1
# Haplopteris                1
# Haptotrichion              2
# Hardenbergia               4
# Harmogia                   2
# Harmsiodoxa               16
# Harnieria                  8
# Harpullia                 29
# Harrisonia                 4
# Harungana                  1
# Hebenstretia               1
# Hedera                     2
# Hedraianthera              4
# Hedycarya                 11
# Hedychium                  5
# Hedyotis                   4
# Hedyscepe                  1
# Heimia                     1
# Helenium                   1
# Helianthus                15
# Helichrysum                7
# Helicia                   30
# Helicteres                18
# Heliophila                 3
# Heliotropium              23
# Helipterum                 1
# Helmholtzia                4
# Helminthostachys           2
# Helminthotheca             5
# Helosciadium               2
# Hemarthria                15
# Hemerocallis               1
# Hemiandra                 24
# Hemichroa                  4
# Hemigenia                 65
# Hemiphora                  8
# Hemisteptia                2
# Hemmantia                  3
# Hensmania                  8
# Heptapleurum               7
# Herbertia                  3
# Herissantia                2
# Heritiera                  2
# Hernandia                 11
# Herniaria                  1
# Herpolirion                1
# Hesperantha                3
# Hesperis                   1
# Hesperocyparis             4
# Heterachne                 7
# Heteropogon                4
# Heterotheca                1
# Heterozostera              2
# Hevea                      1
# Hexaspora                  2
# Hibbertia                379
# Hibiscus                 192
# Hicksbeachia               7
# Hieracium                  2
# Hierochloe                11
# Hildegardia                1
# Hippocratea                1
# Hirschfeldia               4
# Histiopteris               3
# Hodgkinsonia               4
# Hodgsoniola                2
# Hoheria                    1
# Holcolemma                 1
# Holcus                    10
# Hollandaea                 8
# Homalanthus               12
# Homalium                  13
# Homalocalyx               10
# Homalosciadium             2
# Homalospermum              2
# Homopholis                 2
# Homoranthus               17
# Hookerochloa               7
# Hopkinsia                  3
# Hordeum                   28
# Hornstedtia                3
# Hornungia                  5
# Horsfieldia                5
# Hovea                    129
# Hovenia                    2
# Howea                      4
# Howittia                   7
# Hoya                       4
# Huberantha                 5
# Hugonia                    1
# Hullsia                    1
# Humulus                    2
# Huperzia                   1
# Hyacinthoides              2
# Hyalochlamys               1
# Hyalosperma               46
# Hybanthus                 34
# Hydrangea                  1
# Hydriastele                7
# Hydrocotyle               87
# Hydrolea                   1
# Hygrochloa                 2
# Hygrophila                 4
# Hylandia                   4
# Hymenachne                 2
# Hymenophyllum              7
# Hymenosporum               7
# Hyoscyamus                 4
# Hyparrhenia               12
# Hypecoum                   3
# Hypericum                 35
# Hypertelis                 6
# Hypocalymma               50
# Hypochaeris               31
# Hypoestes                 13
# Hypolaena                 17
# Hypolepis                  6
# Hypolytrum                 2
# Hypoxis                   10
# Hypserpa                   1
# Hypsophila                 5
# Hyptis                     2
# Hysterobaeckea            13
# Iberis                     1
# Ibicella                   2
# Ichnanthus                 1
# Ichnocarpus                1
# Idiospermum                2
# Ilex                      16
# Illecebrum                 1
# Illigera                   1
# Impatiens                  9
# Imperata                   6
# Indagator                  2
# Indigastrum                3
# Indigofera               101
# Inocarpus                  1
# Intsia                     3
# Iotasperma                 2
# Ipheion                    2
# Iphigenia                  3
# Ipomoea                   12
# Irenepharsus               7
# Iris                       9
# Irvingbaileya              3
# Isachne                   11
# Ischaemum                 24
# Iseilema                  24
# Isoetes                   12
# Isoetopsis                 6
# Isoglossa                  1
# Isolepis                  59
# Isophysis                  1
# Isopogon                 115
# Isotoma                   17
# Isotropis                 19
# Iva                        3
# Ixia                      14
# Ixiochlamys                9
# Ixiolaena                  2
# Ixodia                     8
# Ixora                     17
# Jacksonia                 79
# Jacquemontia               3
# Jagera                    12
# Jarava                     1
# Jasminum                  23
# Jatropha                   2
# Jedda                      1
# Johnsonia                 12
# Josephinia                 8
# Juglans                    3
# Juncus                   118
# Juniperus                  1
# Justicia                   3
# Kalanchoe                  3
# Kardomia                   4
# Karrabina                  7
# Kennedia                  14
# Khaya                      1
# Kingia                     4
# Kippistia                  5
# Kleinhovia                 3
# Kniphofia                  2
# Knoxia                     2
# Koeleria                   2
# Kohautia                   2
# Kopsia                     3
# Korthalsella              19
# Kummerowia                 1
# Kuntheria                  2
# Kunzea                   107
# Labichea                  29
# Lablab                     1
# Laccospadix                2
# Lachenalia                 1
# Lachnagrostis             69
# Lachnostachys              9
# Lactuca                   15
# Lagarosiphon               1
# Lagarostrobos              3
# Lagenophora               12
# Lagerstroemia              6
# Lagunaria                  7
# Lagurus                    3
# Lamarchea                  4
# Lamarckia                  2
# Lambertia                 42
# Lamium                     3
# Lampranthus                5
# Landoltia                  1
# Lantana                    9
# Lapeirousia                1
# Laportea                   5
# Lapsana                    5
# Larsenaikia                4
# Lasianthus                 4
# Lasiopetalum              85
# Lasiospermum               2
# Lasjia                     7
# Lastreopsis                3
# Lateristachys              1
# Lathyrus                   1
# Latrobea                  13
# Launaea                    1
# Laurus                     2
# Lavandula                  7
# Lavatera                   2
# Lawrencella               13
# Lawrencia                 28
# Laxmannia                 56
# Lechenaultia              76
# Ledebouria                 1
# Leea                       5
# Leersia                    6
# Leichhardtia              14
# Leiocarpa                 24
# Leionema                  71
# Lemna                      2
# Lemooria                   1
# Lenbrassia                 3
# Lenwebbia                  8
# Leonotis                   4
# Leontodon                 15
# Leonurus                   2
# Lepidagathis               1
# Lepiderema                17
# Lepidium                 151
# Lepidobolus               15
# Lepidopetalum              2
# Lepidosperma              98
# Lepidozamia                5
# Lepironia                  1
# Lepisanthes                5
# Leporella                  6
# Leptaspis                  1
# Leptatherum                1
# Leptecophylla             11
# Leptinella                 7
# Leptocarpus               36
# Leptoceras                 5
# Leptochloa                 4
# Leptomeria                56
# Leptopteris                1
# Leptorhynchos             33
# Leptosema                 11
# Leptospermum             173
# Lepturus                  11
# Lepyrodia                 24
# Lespedeza                  4
# Lessertia                  4
# Lethedon                   2
# Leucaena                   6
# Leucanthemum               7
# Leucas                     1
# Leucochrysum              15
# Leucojum                   2
# Leucophyta                 5
# Leucopogon               193
# Leuzea                     6
# Levenhookia               35
# Levieria                   3
# Leycesteria                2
# Libertia                   2
# Licuala                    2
# Ligustrum                 15
# Lilaeopsis                 2
# Limnophila                 5
# Limonium                  11
# Limosella                  3
# Linaria                   11
# Lindera                    2
# Lindernia                 12
# Lindsaea                   6
# Lindsayomyrtus             2
# Linociera                  2
# Linospadix                13
# Linum                     18
# Liparis                    3
# Liparophyllum             14
# Lippia                     1
# Lissanthe                 14
# Lithomyrtus                5
# Litsea                    37
# Livistona                 24
# Lobelia                   67
# Lobularia                  5
# Logania                   46
# Logfia                     4
# Lolium                    35
# Lomandra                 106
# Lomatia                   36
# Lonicera                   4
# Lophatherum                1
# Lophopetalum               3
# Lophostemon               14
# Lordhowea                  9
# Lotus                     19
# Loxocarya                  9
# Ludwigia                  20
# Luffa                      1
# Lumnitzera                 9
# Lunaria                    2
# Lunasia                    3
# Lupinus                   14
# Luvunga                    2
# Luzula                    27
# Lycianthes                 4
# Lycium                    18
# Lycopus                    2
# Lyginia                    6
# Lygodium                   2
# Lyperanthus                5
# Lysiana                    2
# Lysimachia                14
# Lysinema                  10
# Lysiosepalum               5
# Lysiphyllum               15
# Lythrum                   25
# Macadamia                 11
# Macaranga                 22
# Macarthuria               20
# Macgregoria                3
# Machaerina                29
# Mackinlaya                 5
# Maclura                    2
# Macropidia                 2
# Macropteranthes           10
# Macroptilium               5
# Macrothelypteris           1
# Macrozamia                12
# Madia                      3
# Maesa                      3
# Maireana                 227
# Malaccotristicha           1
# Malachra                   2
# Malacocera                13
# Malaisia                   2
# Malcolmia                  1
# Malleostemon              19
# Mallotus                  38
# Malus                      1
# Malva                     23
# Malvastrum                11
# Malvaviscus                1
# Mammea                     4
# Mangifera                  7
# Manihot                    1
# Manilkara                  2
# Mantisalca                 2
# Maranthes                  3
# Margaritaria               6
# Marianthus                16
# Marrubium                  4
# Marsilea                  10
# Martynia                   2
# Matricaria                 8
# Matthiola                  7
# Mauranthemum               2
# Mayaca                     1
# Maytenus                   1
# Mazus                      1
# Mecardonia                 1
# Medicago                  21
# Medicosma                 29
# Medinilla                  1
# Megahertzia                2
# Megathyrsus               10
# Meiogyne                  19
# Meionectes                 7
# Melaleuca                426
# Melanostachya              2
# Melastoma                  9
# Melhania                   7
# Melia                      9
# Melianthus                 8
# Melichrus                 12
# Melicope                  56
# Melicytus                 19
# Melilotus                 16
# Melinis                    6
# Melissa                    4
# Melochia                   6
# Melodinus                  3
# Memecylon                  9
# Menkea                     5
# Mentha                    32
# Mercurialis                1
# Meryta                     2
# Mesembryanthemum          18
# Mesomelaena               15
# Mesosphaerum               2
# Mesua                      6
# Metrosideros               7
# Miconia                    2
# Micraira                  34
# Micrantheum                9
# Microcachrys               2
# Microchloa                 1
# Micrococca                 1
# Microcorys                25
# Microcybe                 18
# Microlaena                21
# Microlepia                 1
# Microlepidium              6
# Micromelum                 6
# Micromyrtus               74
# Microseris                12
# Microstachys               3
# Microstegium               2
# Microtis                  39
# Mikania                    1
# Miliusa                   12
# Milligania                 3
# Millotia                  39
# Mimosa                     6
# Mimulus                    4
# Mimusops                   4
# Minuria                   27
# Mirabilis                  4
# Mirbelia                  51
# Miscanthus                 4
# Mischarytera               6
# Mischocarpus              32
# Misopates                  4
# Mitracarpus                1
# Mitrantia                  2
# Mitrasacme                96
# Mitreola                   1
# Mitrephora                 2
# Mnesithea                  8
# Modiola                    1
# Moenchia                   2
# Molineria                  2
# Molineriella               4
# Mollugo                    2
# Moluccella                 4
# Momordica                  1
# Monachather               11
# Monococcus                 4
# Monoculus                 12
# Monoon                    12
# Monopsis                   3
# Monotaxis                 17
# Monotoca                  34
# Monstera                   1
# Montanoa                   4
# Montia                     8
# ...
# Pyrus                      2
# Quassia                    1
# Quercus                    6
# Quinetia                  10
# Quinqueremulus             1
# Quintinia                  9
# Quoya                     11
# Radyera                    6
# Randia                     9
# Ranunculus               105
# Rapanea                    1
# Raphanus                  10
# Rapistrum                  4
# Rauvolfia                  1
# Reedia                     2
# Regelia                    7
# Reichardia                 6
# Remusatia                  1
# Reseda                    17
# Retama                     2
# Rhadinothamnus            10
# Rhagodia                  63
# Rhamnella                  1
# Rhamnus                    5
# Rhamphicarpa               1
# Rhaphidophora              2
# Rhaphidospora              4
# Rhaphiolepis               2
# Rhizophora                15
# Rhodamnia                 48
# Rhodanthe                126
# Rhododendron               6
# Rhodomyrtus               18
# Rhodosphaera               6
# Rhopalostylis              1
# Rhus                       3
# Rhynchosia                 5
# Rhynchospora               9
# Rhysotoechia              18
# Rhytidosporum             12
# Ribes                      2
# Ricinocarpos              33
# Ricinus                    4
# Rimacola                   1
# Rinorea                    2
# Rinzia                    21
# Ripogonum                  7
# Ristantia                  6
# Rivina                     3
# Robinia                    4
# Rockinghamia               5
# Roebuckiella               5
# Roemeria                   1
# Roepera                   83
# Roldana                    3
# Romnalda                   3
# Romneya                    4
# Romulea                   10
# Rorippa                   28
# Rosa                      10
# Rosmarinus                 1
# Rostellularia              9
# Rostraria                 12
# Rotala                     8
# Rotheca                    1
# Rothia                     2
# Rottboellia                2
# Rourea                     1
# Roycea                     4
# Rubiaceae                  1
# Rubus                     32
# Ruellia                    1
# Rumex                     73
# Rumohra                    1
# Ruppia                     3
# Ruschia                    1
# Rutidosis                 11
# Ryparosa                   3
# Ryticaryum                 2
# Rytidosperma             141
# Sabulina                   2
# Saccharum                  2
# Sacciolepis                5
# Sageretia                  1
# Sagina                     7
# Sagittaria                 4
# Salacia                    2
# Salicornia                19
# Salix                     41
# Salomonia                  1
# Salsola                   13
# Salvia                    24
# Salvinia                   1
# Samadera                  12
# Samanea                    2
# Sambucus                  15
# Samolus                   18
# Sanchezia                  1
# Sanguisorba                1
# Sankowskya                 2
# Sannantha                 12
# Santalum                  35
# Sapindaceae                1
# Sarcochilus                3
# Sarcocornia                1
# Sarcomelicope              6
# Sarcopteryx               17
# Sarcotoechia              14
# Sarcozona                  8
# Sarracenia                 2
# Saurauia                   3
# Sauropus                  11
# Saururus                   2
# Saxifraga                  1
# Saxipoa                    4
# Scaevola                 214
# Scambopus                  2
# Scandix                    3
# Scapisenecio              11
# Sceptridium                2
# Schelhammera               4
# Schenkia                  10
# Schinus                   11
# Schismus                   6
# Schistocarpaea             3
# Schizachyrium             13
# Schizacme                  3
# Schizaea                   5
# Schizomeria                7
# Schkuhria                  3
# Schoenia                  13
# Schoenolaena               3
# Schoenoplectiella          9
# Schoenoplectus            10
# Schoenus                 177
# Scholtzia                 45
# Schoutenia                 1
# Sciaphila                  2
# Scilla                     1
# Scindapsus                 1
# Scleranthus                7
# Scleria                   12
# Scleroblitum               2
# Sclerochloa                2
# Sclerolaena              245
# Scleroschoenus             5
# Scolopia                   4
# Scolymus                   5
# Scoparia                   3
# Scorpiurus                 2
# Scorzonera                 4
# Scrophularia               1
# Scrotochloa                2
# Scutellaria                2
# Scyphiphora                4
# Sebaea                    11
# Secale                     4
# Securigera                 2
# Sedopsis                   1
# Sedum                      5
# Sehima                     3
# Selaginella               11
# Selago                     3
# Semecarpus                 3
# Senecio                  344
# Senegalia                  2
# Senna                    186
# Seorsus                    1
# Sequoia                    2
# Serichonus                 2
# Seringia                  21
# Sersalisia                 8
# Sesamum                    1
# Sesbania                  21
# Sesuvium                   2
# Setaria                   40
# Sherardia                  1
# Shonia                     3
# Sida                     118
# Sideritis                  1
# Siegfriedia                2
# Sieruela                   2
# Sigesbeckia               12
# Silene                    24
# Siloxerus                 11
# Silybum                    4
# Sinapis                    6
# Sindora                    1
# Siphonodon                10
# Sisymbrium                28
# Sisyrinchium               5
# Sixalix                    3
# Sloanea                   19
# Smilax                    11
# Smithia                    1
# Solanum                  383
# Solenogyne                10
# Solidago                   6
# Soliva                     1
# Sonchus                   26
# Sondottia                  2
# Sonneratia                13
# Sophora                   11
# Sorbus                     2
# Sorghastrum                1
# Sorghum                   49
# Sowerbaea                 10
# Sparaxis                  10
# Sparganium                 3
# Spartium                   2
# Spartochloa                2
# Spathia                    1
# Spathodea                  1
# Spergula                   3
# Spergularia               13
# Spermacoce                68
# Sphaeralcea                1
# Sphaeranthus               6
# Sphaerantia                4
# Sphaerolobium             50
# Sphaeromorphaea            4
# Sphagneticola              2
# Sphalmium                  2
# Sphenoclea                 2
# Sphenopus                  1
# Sphenostemon               3
# Sphenotoma                13
# Spiculaea                  1
# Spinifex                  10
# Spiraea                    2
# Spiraeanthemum             2
# Spiranthes                 2
# Spirogardnera              2
# Spondias                   1
# Sporadanthus               5
# Sporobolus                72
# Sprengelia                10
# Spyridium                 63
# Stachys                    6
# Stachystemon              11
# Stachytarpheta            14
# Stackhousia               59
# Stawellia                  5
# Steganthera               20
# Stellaria                 20
# Stemodia                  22
# Stemona                    1
# Stenanthemum              72
# Stenanthera                9
# Stenocarpus               32
# Stenochlaena               2
# Stenopetalum              38
# Stenotaphrum               5
# Stephania                  1
# Stephanophysum             2
# Sterculia                 14
# Sternbergia                1
# Stevia                     2
# Sticherus                  2
# Stirlingia                16
# Stockwellia                2
# Stonesiella                1
# Storckiella                2
# Strangea                   8
# Streblus                   8
# Strelitzia                 1
# Streptoglossa             19
# Striga                     4
# Strobilanthes              2
# Strychnos                 12
# Stuartina                  7
# Stuckenia                  2
# Stylidium                353
# Stylobasium                3
# Stylosanthes              12
# Stypandra                  6
# Styphelia                222
# Suaeda                    18
# Succowia                   1
# Suregada                   2
# Suriana                    4
# Surreya                    5
# Swainsona                108
# Syagrus                    1
# Sylvipoa                   2
# Symonanthus                4
# Symphionema                4
# Symphoricarpos             2
# Symphyotrichum             7
# Symphytum                  3
# Symplocos                 49
# Synaphea                 101
# Synaptantha                4
# Syncarpia                  6
# Synedrella                 4
# Syngonium                  1
# Synima                     8
# Synostemon                13
# Synoum                     9
# Syzygium                 196
# Tabernaemontana           13
# Tacca                      4
# Tadehagi                   1
# Taenitis                   1
# Tagetes                    9
# Talinum                    1
# Tamarindus                 5
# Tamarix                    6
# Tanacetum                  6
# Tapeinochilos              3
# Tapeinosperma              9
# Taplinia                   1
# Taraxacum                  7
# Taraxis                    2
# Tarenaya                   2
# Tarenna                    9
# Tarennoidea                1
# Tasmannia                 45
# Taxandria                 22
# Tecoma                     4
# Tectaria                   2
# Tecticornia              166
# Teesdalia                  1
# Telanthera                 1
# Telmatoblechnum            1
# Telopea                   17
# Templetonia               26
# Tephrosia                 76
# Terminalia                85
# Ternstroemia               3
# Tersonia                   2
# Tetracarpaea               3
# Tetracera                  1
# Tetragonia                16
# Tetrameles                 3
# Tetrapanax                 3
# Tetrapora                  4
# Tetrardisia                3
# Tetraria                  10
# Tetrarrhena               20
# Tetrastigma                1
# Tetratheca                89
# Teucrium                  43
# Thalassodendron            1
# Thaleropia                 2
# Thalia                     1
# Thaumastochloa            10
# Thelepogon                 1
# Thelionema                10
# Thelymitra                98
# Themeda                   24
# Thesium                    4
# Thespesia                  7
# Thespidium                 3
# Thinicola                  1
# Thinopyrum                 6
# Thiseltonia                1
# Thismia                    4
# Thlaspi                    3
# Thomasia                  54
# Thoracostachyum            1
# Threlkeldia                9
# Thryptomene               69
# Thuarea                    1
# Thunbergia                 1
# Thymelaea                  3
# Thymophylla                1
# Thymus                     1
# Thynninorchis              1
# Thyridia                   2
# Thyridolepis              14
# Thysanotus               101
# Timonius                   7
# Tinospora                  1
# Tithonia                   5
# Tmesipteris                2
# Todea                      4
# Toechima                  21
# Tolpis                     7
# Toona                      5
# Tordylium                  1
# Torenia                    2
# Torilis                    5
# Toxicodendron              2
# Trachyandra                3
# Trachycarpus               1
# Trachymene                93
# Trachystemon               1
# Tradescantia               3
# Tragopogon                12
# Tragus                     6
# Trema                     15
# Tremandra                  4
# Tremulina                  4
# Triadenum                  1
# Triadica                   1
# Trianthema                10
# Tribolium                  7
# Tribonanthes              11
# Tribulopis                 2
# Tribulus                  12
# Trichanthodium             6
# Trichocline                5
# Trichodesma               10
# Trichospermum              2
# Tricoryne                 30
# Tricostularia             19
# Tridax                     3
# Triflorensia               8
# Trifolium                 59
# Trigastrotheca             1
# Triglochin                66
# Trigonella                 4
# Trigonostemon              1
# Trihaloragis               7
# Triodanis                  1
# Triodia                  184
# Trioncinia                 2
# Triphasia                  1
# Triphysaria                1
# Tripladenia                2
# Triplarina                 2
# Tripleurospermum           3
# Tripogonella               6
# Tripterococcus             8
# Triptilodiscus             7
# Triraphis                  7
# Trisetum                   7
# Tristania                  1
# Tristaniopsis             12
# Tristemma                  2
# Tristiropsis               4
# Tritaxis                   3
# Trithuria                 13
# Triticum                   5
# Tritonia                   6
# Triumfetta                62
# Triunia                    9
# Trochocarpa               24
# Trymalium                 36
# Turnera                    4
# Turraea                    6
# Turritis                   3
# Typha                     12
# Typhonium                  2
# Tyrbastes                  3
# Ulex                       3
# Ulmus                      5
# Ungeria                    1
# Uranthoecium               3
# Uraria                     2
# Urena                      9
# Urochloa                  61
# Urodon                     4
# Uromyrtus                 10
# Urospermum                 8
# Ursinia                   13
# Urtica                    12
# Utania                     4
# Utricularia               46
# Uvaria                     5
# Uvedalia                   4
# Vachellia                 40
# Valerianella               1
# Van-royena                 2
# Vavaea                     6
# Vellereophyton             6
# Ventilago                  6
# Verbascum                 18
# Verbena                   45
# Verbesina                  5
# Vernicia                   1
# Vernonia                   1
# Veronica                  44
# Verticordia              204
# Vesselowskya               4
# Viburnum                   5
# Vicia                     15
# Vigna                      7
# Viminaria                  8
# Vinca                      2
# Vincetoxicum              17
# Viola                     27
# Viscum                     2
# Vitex                     29
# Vittadinia                70
# Voacanga                   3
# Vulpia                    46
# Wachendorfia               1
# Wahlenbergia              69
# Waitzia                   34
# Walteranthus               1
# Waltheria                  6
# Walwhalleya                8
# Washingtonia               2
# Watsonia                  27
# Welchiodendron             2
# Wendlandia                 9
# Westringia                45
# Wetria                     2
# Whiteochloa               11
# Whyanbeelia                2
# Wigandia                   2
# Wikstroemia                7
# Wilkiea                   44
# Wilsonia                  14
# Winifredia                 1
# Withania                   3
# Wittsteinia                3
# Wodyetia                   2
# Wolffia                    1
# Wollastonia                5
# Wollemia                   2
# Woollsia                   3
# Wrightia                  20
# Wurmbea                   76
# Xanthium                  18
# Xanthophyllum              7
# Xanthorrhoea              46
# Xanthosia                 52
# Xanthostemon              34
# Xerochloa                  5
# Xerochrysum               19
# Xerolirion                 1
# Xerothamnella              2
# Ximenia                    2
# Xylocarpus                14
# Xylomelum                 12
# Xylopia                    7
# Xylosma                   14
# Xyris                     36
# Yakirra                   15
# Youngia                    2
# Yucca                      3
# Zaleya                     3
# Zaluzianskya               9
# Zantedeschia               1
# Zanthoxylum               20
# Zea                        1
# Zealandia                  3
# Zeuxine                    1
# Zieria                   157
# Zingiber                   3
# Zinnia                     4
# Ziziphus                  13
# Zornia                    16
# Zoysia                     7
# Zuloagaea                  1
# Zygochloa                  2
# x Cynochloris              2
# x Phelodia                 1

# %% [markdown]
# * The distributions are far from equal and the variation in each genus per trait_name/value_type could be too large for good modelling.
# * Filtering to only genera with a minimum(?) count per trait_name/value_type feature and selecting only the largest trait_name/value_type features may improve modelling for those genera that are included.

# %%
# Drop taxon_name, taxon_rank as genus will be the class, combine trait_name and value_type as the trait
genus_trait_df = trait_filt_df.drop(columns=['taxon_name', 'taxon_rank', 'observation_id', 'basis_of_value'])
genus_trait_df['trait'] = genus_trait_df['trait_name'] + '_' + genus_trait_df['value_type']
genus_trait_df = genus_trait_df.drop(columns=['trait_name', 'value_type'])
genus_trait_df.head()
# Out:
#   value unit       genus      family                 trait
# 0     5   mm  Adenanthos  Proteaceae   leaf_length_minimum
# 1    20   mm  Adenanthos  Proteaceae   leaf_length_maximum
# 2   0.5   mm  Adenanthos  Proteaceae    leaf_width_maximum
# 3   0.5    m  Adenanthos  Proteaceae  plant_height_maximum
# 4    10   mm  Adenanthos  Proteaceae   leaf_length_minimum

# %% [markdown]
# # 4. Summary
# > As per README.md, this data is not suited to provide a model to solve the problem statement. The data could be suitable if it were the raw data and data sources were consistent with data collection.
